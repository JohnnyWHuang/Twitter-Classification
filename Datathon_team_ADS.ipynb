# %% [markdown]
# # MDSS Datathon - Team ADS
# #### Johnny Huang, Jonothan Kerslake, Patrick Chen

# %% [markdown]
# # Preface

# %% [markdown]
# The following notebook parses precleaned twitter data scraped with the Tweepy library. The aim is to:
# 1. Clean both training and testing data
# 2. Transform text into suitable data as an input to a machine learning model
# 3. Output labels from model into csv and submit to kaggle

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import re
import nltk
import string
import numpy as np

# %%
# Training dataframe
df = pd.read_csv("mdss-basic-stream/train_basic.csv")
# Testing dataframe
df2 = pd.read_csv("mdss-basic-stream/test_basic.csv")

# List of unique labels/tags
tags = list(df['label'].unique())

# %%
df['tweet'][3]
# Out:
# 'rt errolwebber: tell me, would this be considered "racist?\\xe2\\x80\\x9d\\n\\ndo people who support blm think this is ok? https://t.co/duwabljghp\''

# %%
# Referenced from https://stackoverflow.com/questions/753052/strip-html-from-strings-in-python

# Strip HTML tags and other characters, such as &amp
from io import StringIO
from html.parser import HTMLParser

class MLStripper(HTMLParser):
    def __init__(self):
        super().__init__()
        self.reset()
        self.strict = False
        self.convert_charrefs= True
        self.text = StringIO()
    def handle_data(self, d):
        self.text.write(d)
    def get_data(self):
        return self.text.getvalue()

def strip_tags(html):
    s = MLStripper()
    s.feed(html)
    return s.get_data()

# %% [markdown]
# # Data Cleaning

# %%
# Drop NaN
df.dropna(inplace=True)

# Drop Duplicates
df.drop_duplicates(subset=['tweet'])

# Strip HTML
df['tweet'] = df['tweet'].apply(lambda x: strip_tags(x))

#Removes Punctuation
df['tweet'] = df['tweet'].apply(lambda x: re.sub('[!@#$:).;,?]', '', str(x)))
#Removes hyperlinks
df['tweet'] = df['tweet'].apply(lambda x: re.sub(r'http\S+', '', str(x)))
#Remove newlines
df['tweet'] = df['tweet'].apply(lambda x: x.strip().replace('\\n', ''))
#Remove encoded characters
df['tweet'] = df['tweet'].apply(lambda x: re.sub(r'(\\x(.){2})', '', str(x)))
#Removes ' , ", and blank space
df['tweet'] = df['tweet'].apply(lambda x: x.replace("'", ""))
df['tweet'] = df['tweet'].apply(lambda x: x.replace('"', ""))
df['tweet'] = df['tweet'].apply(lambda x: x.strip())
#Remove escape charcters but keep emoji codes
df['tweet'] = df['tweet'].apply(lambda x: re.sub("\\\\", '', str(x)))
# Remove 'rt', retweet string. Remove newline character
df['tweet'] = df['tweet'].apply(lambda x: x.strip("rt ").replace('\n', ''))

# Remove other punctuation 
exclude = set(string.punctuation)
df['tweet'] = df['tweet'].apply(lambda x: ''.join(ch for ch in x if ch not in exclude))
df['tweet'] = df['tweet'].apply(lambda x: re.sub('[”’“‘1234567890]', '', str(x)))

# %%
df
# Out:
#                                                    tweet  label
# 0      silencing blm  priti patels antiprotest law  i...    BLM
# 1      illian johnbok nadiawhittomemp silly little wo...    BLM
# 2      errolwebber tell me would this be considered r...    BLM
# 3      apple wont let parler have an app but still ke...    BLM
# 4      malikaandrews wojespn can we get jlm trending ...    BLM
# ...                                                  ...    ...
# 26395  hey have brainwashed their base for generation...  Riots
# 26396  blackcat these neanderthals were there for blm...  Riots
# 26397  atrupar  dear jaketapper instead of airing tat...  Riots
# 26398  his is a bombshellmarjorie greene may have bee...  Riots
# 26399  omthunkitsmind lets talk about white supremacy...  Riots
#
# [24329 rows x 2 columns]

# %% [markdown]
# ### Tokenize testing data
# This will separate each string into a list of words

# %%
from nltk import word_tokenize

# %%
df['token'] = df['tweet'].apply(word_tokenize)
df['token'][0]
# Out:
# ['silencing',
#  'blm',
#  'priti',
#  'patels',
#  'antiprotest',
#  'law',
#  'iandunt',
#  'on',
#  'how',
#  'a',
#  'government',
#  'keen',
#  'to',
#  'tackle',
#  'cancel',
#  'culture',
#  'when']

# %% [markdown]
# ### Remove stopwords
# This will remove all conjuction words from NLTK's library of stopwords

# %%
from nltk.corpus import stopwords
sw = stopwords.words('english')
df['token'] = df['token'].apply(lambda x:[word for word in x if word not in sw])
df['token'][0]
# Out:
# ['silencing',
#  'blm',
#  'priti',
#  'patels',
#  'antiprotest',
#  'law',
#  'iandunt',
#  'government',
#  'keen',
#  'tackle',
#  'cancel',
#  'culture']

# %% [markdown]
# ### Create Stem Words from Token
# Words will revert to their root/stem word.
# Thus, variances of words such as big / bigger / biggest will collate to the same root word.

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english", ignore_stopwords=True)
df['stem'] =  df['token'].apply(lambda x: [stemmer.stem(i) for i in x])
df['stem'][0]
# Out:
# ['silenc',
#  'blm',
#  'priti',
#  'patel',
#  'antiprotest',
#  'law',
#  'iandunt',
#  'govern',
#  'keen',
#  'tackl',
#  'cancel',
#  'cultur']

# %% [markdown]
# ### Word Frequency
#
# Find the word frequency to double check data cleaning process

# %%
#Dictionary for token
wordfreq = {}
for token in df['stem']:
    for i in range(len(token)):
        if token[i] not in wordfreq.keys():
            wordfreq[token[i]] = 1
        else:
            wordfreq[token[i]] += 1
            
sorted_stem = sorted(wordfreq.items(), key=lambda kv: kv[1])
sorted_stem.reverse()
sorted_stem
# Out:
# [('covid', 4788),
#  ('trump', 4537),
#  ('biden', 3032),
#  ('joebiden', 1997),
#  ('vaccin', 1738),
#  ('blm', 1536),
#  ('peopl', 1411),
#  ('get', 1363),
#  ('wearamask', 1327),
#  ('capitolriot', 1309),
#  ('vote', 1290),
#  ('us', 1102),
#  ('like', 998),
#  ('mask', 956),
#  ('know', 956),
#  ('one', 916),
#  ('dont', 914),
#  ('black', 911),
#  ('new', 890),
#  ('blacklivesmatt', 889),
#  ('say', 858),
#  ('elect', 842),
#  ('pleas', 812),
#  ('go', 783),
#  ('time', 755),
#  ('need', 689),
#  ('want', 680),
#  ('year', 680),
#  ('day', 658),
#  ('watch', 616),
#  ('make', 592),
#  ('capitol', 573),
#  ('still', 568),
#  ('see', 562),
#  ('support', 562),
#  ('hunterbiden', 561),
#  ('live', 551),
#  ('im', 549),
#  ('case', 545),
#  ('presid', 544),
#  ('let', 540),
#  ('democrat', 535),
#  ('would', 531),
#  ('donaldtrump', 527),
#  ('twitter', 527),
#  ('help', 526),
#  ('polic', 517),
#  ('state', 516),
#  ('american', 516),
#  ('fbi', 506),
#  ('today', 503),
#  ('think', 500),
#  ('call', 485),
#  ('gop', 484),
#  ('via', 476),
#  ('never', 463),
#  ('bidenharri', 462),
#  ('use', 458),
#  ('wear', 457),
#  ('lie', 453),
#  ('white', 450),
#  ('work', 449),
#  ('take', 445),
#  ('america', 436),
#  ('look', 436),
#  ('seditionhunt', 435),
#  ('good', 433),
#  ('realdonaldtrump', 431),
#  ('person', 429),
#  ('share', 424),
#  ('station', 422),
#  ('ump', 419),
#  ('republican', 417),
#  ('right', 416),
#  ('mani', 414),
#  ('even', 414),
#  ('stop', 400),
#  ('joe', 399),
#  ('corrupt', 398),
#  ('said', 396),
#  ('first', 392),
#  ('famili', 386),
#  ('come', 385),
#  ('man', 383),
#  ('offic', 378),
#  ('death', 373),
#  ('cant', 372),
#  ('stori', 371),
#  ('news', 370),
#  ('show', 369),
#  ('got', 368),
#  ('report', 365),
#  ('tri', 363),
#  ('maga', 359),
#  ('health', 359),
#  ('back', 354),
#  ('million', 350),
#  ('thank', 349),
#  ('give', 342),
#  ('hunter', 338),
#  ('care', 338),
#  ('hous', 336),
#  ('love', 330),
#  ('keep', 328),
#  ('countri', 324),
#  ('post', 323),
#  ('pandem', 320),
#  ('test', 319),
#  ('way', 313),
#  ('video', 312),
#  ('face', 312),
#  ('thing', 312),
#  ('coronavirus', 311),
#  ('th', 307),
#  ('anoth', 305),
#  ('kk', 304),
#  ('doesnt', 304),
#  ('world', 303),
#  ('week', 302),
#  ('racist', 298),
#  ('nypost', 296),
#  ('follow', 292),
#  ('continu', 291),
#  ('last', 291),
#  ('plan', 288),
#  ('also', 287),
#  ('town', 285),
#  ('protect', 285),
#  ('everyon', 285),
#  ('well', 283),
#  ('die', 281),
#  ('great', 281),
#  ('much', 279),
#  ('could', 277),
#  ('big', 277),
#  ('talk', 277),
#  ('polit', 276),
#  ('realli', 274),
#  ('johnson', 272),
#  ('everi', 271),
#  ('son', 270),
#  ('media', 269),
#  ('racism', 269),
#  ('facebook', 268),
#  ('must', 267),
#  ('kamalaharri', 265),
#  ('texa', 265),
#  ('truth', 261),
#  ('sinc', 261),
#  ('hes', 259),
#  ('across', 254),
#  ('kill', 254),
#  ('investig', 254),
#  ('depart', 252),
#  ('nation', 248),
#  ('your', 248),
#  ('find', 248),
#  ('busi', 245),
#  ('made', 244),
#  ('public', 243),
#  ('that', 243),
#  ('senat', 241),
#  ('email', 240),
#  ('potus', 239),
#  ('start', 239),
#  ('nbc', 238),
#  ('relief', 236),
#  ('hope', 236),
#  ('win', 234),
#  ('ealdonaldtrump', 232),
#  ('happen', 232),
#  ('part', 232),
#  ('platform', 231),
#  ('tell', 231),
#  ('may', 229),
#  ('protest', 229),
#  ('believ', 228),
#  ('hear', 226),
#  ('matter', 226),
#  ('ukrain', 225),
#  ('virus', 225),
#  ('life', 225),
#  ('member', 225),
#  ('w', 225),
#  ('campaign', 225),
#  ('updat', 224),
#  ('ask', 224),
#  ('bill', 222),
#  ('releas', 220),
#  ('china', 218),
#  ('noth', 218),
#  ('put', 218),
#  ('contact', 217),
#  ('spread', 216),
#  ('check', 216),
#  ('month', 215),
#  ('communiti', 213),
#  ('friend', 212),
#  ('chang', 211),
#  ('iowa', 209),
#  ('home', 209),
#  ('next', 208),
#  ('fact', 208),
#  ('mean', 207),
#  ('hey', 205),
#  ('receiv', 204),
#  ('govern', 204),
#  ('censorship', 199),
#  ('end', 199),
#  ('hunterbidenemail', 198),
#  ('cnn', 198),
#  ('didnt', 198),
#  ('fight', 197),
#  ('read', 197),
#  ('number', 196),
#  ('respons', 195),
#  ('arrest', 195),
#  ('counti', 195),
#  ('open', 193),
#  ('posit', 193),
#  ('debat', 192),
#  ('msnbc', 192),
#  ('safe', 192),
#  ('break', 192),
#  ('stay', 192),
#  ('abc', 191),
#  ('question', 191),
#  ('anyon', 189),
#  ('pass', 189),
#  ('around', 188),
#  ('better', 186),
#  ('u', 186),
#  ('link', 185),
#  ('school', 184),
#  ('ralli', 183),
#  ('bad', 183),
#  ('march', 183),
#  ('hate', 182),
#  ('real', 181),
#  ('ever', 180),
#  ('censor', 179),
#  ('obama', 179),
#  ('social', 179),
#  ('sure', 179),
#  ('burisma', 178),
#  ('attack', 177),
#  ('dose', 176),
#  ('money', 176),
#  ('rememb', 175),
#  ('name', 175),
#  ('anyth', 174),
#  ('alway', 174),
#  ('usa', 174),
#  ('pm', 174),
#  ('long', 174),
#  ('includ', 173),
#  ('two', 173),
#  ('isnt', 172),
#  ('dr', 171),
#  ('run', 171),
#  ('yet', 171),
#  ('riot', 170),
#  ('deal', 169),
#  ('parti', 169),
#  ('wont', 169),
#  ('charg', 168),
#  ('account', 167),
#  ('feel', 166),
#  ('guy', 166),
#  ('job', 164),
#  ('justic', 164),
#  ('free', 163),
#  ('speak', 163),
#  ('left', 162),
#  ('record', 162),
#  ('histori', 162),
#  ('articl', 161),
#  ('actual', 160),
#  ('jan', 160),
#  ('someon', 160),
#  ('other', 160),
#  ('hall', 159),
#  ('shot', 159),
#  ('yall', 159),
#  ('fuck', 156),
#  ('claim', 156),
#  ('lost', 155),
#  ('due', 155),
#  ('resist', 154),
#  ('women', 154),
#  ('act', 153),
#  ('alreadi', 153),
#  ('morn', 153),
#  ('voter', 152),
#  ('without', 152),
#  ('rate', 152),
#  ('enrout', 151),
#  ('turn', 151),
#  ('offici', 151),
#  ('play', 150),
#  ('tweet', 150),
#  ('old', 150),
#  ('wait', 149),
#  ('nbcnew', 149),
#  ('forget', 149),
#  ('congress', 148),
#  ('hour', 148),
#  ('lose', 148),
#  ('move', 147),
#  ('youtub', 147),
#  ('crime', 147),
#  ('join', 146),
#  ('point', 146),
#  ('import', 146),
#  ('murder', 146),
#  ('poll', 145),
#  ('insurrect', 145),
#  ('blackhistorymonth', 145),
#  ('pay', 145),
#  ('b', 145),
#  ('law', 145),
#  ('india', 144),
#  ('hard', 144),
#  ('group', 144),
#  ('away', 143),
#  ('told', 142),
#  ('best', 142),
#  ('allow', 142),
#  ('effect', 141),
#  ('power', 141),
#  ('yes', 140),
#  ('c', 140),
#  ('cover', 139),
#  ('here', 139),
#  ('sign', 139),
#  ('worker', 138),
#  ('differ', 138),
#  ('hospit', 137),
#  ('na', 137),
#  ('dead', 137),
#  ('stand', 137),
#  ('impeach', 136),
#  ('top', 136),
#  ('alleg', 136),
#  ('lot', 136),
#  ('ago', 135),
#  ('save', 135),
#  ('bidenharristosaveamerica', 134),
#  ('done', 134),
#  ('ive', 134),
#  ('theyr', 134),
#  ('clear', 134),
#  ('tax', 133),
#  ('unit', 133),
#  ('donald', 133),
#  ('citi', 133),
#  ('word', 133),
#  ('trumpisalaughingstock', 132),
#  ('icecub', 132),
#  ('place', 132),
#  ('st', 132),
#  ('took', 132),
#  ('event', 132),
#  ('leader', 132),
#  ('reason', 132),
#  ('learn', 132),
#  ('thought', 131),
#  ('inform', 131),
#  ('wrong', 131),
#  ('fire', 130),
#  ('wonder', 130),
#  ('bidentownhal', 129),
#  ('hold', 129),
#  ('kid', 129),
#  ('bring', 129),
#  ('foxnew', 129),
#  ('k', 128),
#  ('second', 128),
#  ('enough', 128),
#  ('rule', 127),
#  ('someth', 127),
#  ('found', 127),
#  ('seen', 127),
#  ('action', 126),
#  ('h', 125),
#  ('listen', 125),
#  ('creat', 125),
#  ('excus', 124),
#  ('york', 124),
#  ('lead', 123),
#  ('understand', 123),
#  ('jack', 122),
#  ('instead', 121),
#  ('almost', 121),
#  ('forc', 121),
#  ('everyth', 121),
#  ('children', 121),
#  ('push', 121),
#  ('nurs', 120),
#  ('donat', 120),
#  ('aid', 119),
#  ('woman', 119),
#  ('ignor', 118),
#  ('remov', 117),
#  ('shit', 117),
#  ('close', 117),
#  ('discuss', 117),
#  ('hand', 116),
#  ('seem', 116),
#  ('administr', 115),
#  ('true', 115),
#  ('terrorist', 115),
#  ('issu', 115),
#  ('tonight', 114),
#  ('witter', 114),
#  ('vp', 114),
#  ('evid', 114),
#  ('night', 114),
#  ('list', 113),
#  ('step', 113),
#  ('littl', 113),
#  ('friday', 112),
#  ('ukrainian', 111),
#  ('f', 111),
#  ('final', 111),
#  ('ill', 111),
#  ('total', 110),
#  ('block', 110),
#  ('wake', 110),
#  ('least', 110),
#  ('stupid', 110),
#  ('secur', 110),
#  ('caus', 110),
#  ('begin', 109),
#  ('happi', 109),
#  ('book', 109),
#  ('oh', 109),
#  ('meet', 109),
#  ('student', 108),
#  ('announc', 108),
#  ('becom', 108),
#  ('crimin', 108),
#  ('boycottnbc', 107),
#  ('id', 107),
#  ('earli', 107),
#  ('patient', 107),
#  ('involv', 107),
#  ('trial', 107),
#  ('decis', 106),
#  ('system', 106),
#  ('prosecutor', 106),
#  ('proud', 106),
#  ('januari', 105),
#  ('former', 105),
#  ('near', 105),
#  ('compani', 105),
#  ('far', 105),
#  ('canada', 105),
#  ('tomorrow', 104),
#  ('florida', 104),
#  ('high', 104),
#  ('rioter', 103),
#  ('voteblu', 103),
#  ('blue', 103),
#  ('trillion', 102),
#  ('head', 102),
#  ('gon', 102),
#  ('air', 102),
#  ('feder', 102),
#  ('freedom', 102),
#  ('god', 102),
#  ('afo', 101),
#  ('cape', 101),
#  ('provid', 101),
#  ('behind', 101),
#  ('educ', 101),
#  ('messag', 101),
#  ('celebr', 101),
#  ('confirm', 100),
#  ('activ', 100),
#  ('latest', 100),
#  ('war', 100),
#  ('agre', 100),
#  ('trumppenc', 99),
#  ('pa', 99),
#  ('medic', 99),
#  ('what', 99),
#  ('surpris', 99),
#  ('race', 99),
#  ('full', 99),
#  ('amaz', 99),
#  ('court', 99),
#  ('flattenthecurv', 98),
#  ('variant', 98),
#  ('offer', 98),
#  ('onlin', 98),
#  ('interest', 98),
#  ('fake', 98),
#  ('order', 98),
#  ('increas', 97),
#  ('data', 97),
#  ('approv', 97),
#  ('sever', 97),
#  ('immun', 96),
#  ('studi', 96),
#  ('whole', 96),
#  ('wi', 96),
#  ('infect', 95),
#  ('harri', 95),
#  ('liar', 95),
#  ('bts', 94),
#  ('arriv', 94),
#  ('boy', 94),
#  ('knew', 94),
#  ('team', 94),
#  ('insurrectionist', 94),
#  ('fo', 94),
#  ('n', 94),
#  ('breakingjuri', 94),
#  ('mandat', 93),
#  ('photo', 93),
#  ('chief', 93),
#  ('fund', 93),
#  ('daili', 93),
#  ('refus', 93),
#  ('p', 93),
#  ('mayb', 93),
#  ('sad', 92),
#  ('cop', 92),
#  ('local', 92),
#  ('global', 92),
#  ('februari', 91),
#  ('safeti', 91),
#  ('research', 91),
#  ('commit', 91),
#  ('whitehous', 91),
#  ('there', 91),
#  ('less', 91),
#  ('page', 90),
#  ('leav', 90),
#  ('set', 90),
#  ('organ', 90),
#  ('requir', 89),
#  ('ccp', 89),
#  ('shouldnt', 89),
#  ('problem', 89),
#  ('dc', 88),
#  ('remind', 88),
#  ('polici', 88),
#  ('green', 88),
#  ('control', 88),
#  ('game', 87),
#  ('concern', 87),
#  ('antifa', 87),
#  ('maddow', 86),
#  ('travel', 86),
#  ('democraci', 86),
#  ('known', 86),
#  ('floyd', 86),
#  ('facemask', 85),
#  ('covidiot', 85),
#  ('trumpcovid', 85),
#  ('return', 85),
#  ('author', 85),
#  ('rais', 85),
#  ('trust', 85),
#  ('arent', 85),
#  ('side', 85),
#  ('healthcar', 85),
#  ('dem', 85),
#  ('human', 85),
#  ('probabl', 84),
#  ('al', 84),
#  ('donaldjtrumpjr', 83),
#  ('prevent', 83),
#  ('explain', 83),
#  ('possibl', 83),
#  ('thursday', 83),
#  ('washington', 83),
#  ('hank', 83),
#  ('kind', 83),
#  ('fail', 83),
#  ('georg', 83),
#  ('northernlinect', 82),
#  ('tx', 82),
#  ('ga', 82),
#  ('deni', 82),
#  ('hell', 82),
#  ('servic', 82),
#  ('might', 82),
#  ('storm', 82),
#  ('lineupdateinboundt', 81),
#  ('guard', 81),
#  ('serious', 81),
#  ('tech', 81),
#  ('staysaf', 81),
#  ('folk', 81),
#  ('imagin', 81),
#  ('miss', 81),
#  ('liber', 81),
#  ('saw', 81),
#  ('past', 81),
#  ('mind', 81),
#  ('kag', 80),
#  ('endors', 80),
#  ('scienc', 80),
#  ('singl', 80),
#  ('direct', 80),
#  ('rep', 80),
#  ('sound', 80),
#  ('line', 80),
#  ('send', 80),
#  ('age', 80),
#  ('violenc', 80),
#  ('townhal', 79),
#  ('fl', 79),
#  ('expert', 79),
#  ('expect', 79),
#  ('ad', 79),
#  ('level', 79),
#  ('accept', 79),
#  ('program', 79),
#  ('reveal', 79),
#  ('press', 79),
#  ('bidenharrislandslid', 78),
#  ('schedul', 78),
#  ('threat', 78),
#  ('cdc', 78),
#  ('lockdown', 78),
#  ('ass', 78),
#  ('presidenti', 77),
#  ('governor', 77),
#  ('relat', 77),
#  ('restrict', 77),
#  ('togeth', 77),
#  ('current', 77),
#  ('toward', 77),
#  ('politician', 76),
#  ('access', 76),
#  ('judg', 76),
#  ('movement', 76),
#  ('african', 76),
#  ('yo', 76),
#  ('ok', 76),
#  ('emerg', 75),
#  ('idiot', 75),
#  ('rise', 75),
#  ('recent', 75),
#  ('comment', 75),
#  ('ca', 75),
#  ('yesterday', 75),
#  ('uk', 75),
#  ('billion', 74),
#  ('paid', 74),
#  ('arizona', 74),
#  ('came', 74),
#  ('address', 74),
#  ('peac', 74),
#  ('complet', 74),
#  ('beauti', 74),
#  ('result', 73),
#  ('arm', 73),
#  ('sourc', 73),
#  ('hide', 73),
#  ('risk', 73),
#  ('failur', 73),
#  ('idea', 73),
#  ('lgbtq', 73),
#  ('view', 73),
#  ('accord', 73),
#  ('design', 72),
#  ('crazi', 72),
#  ('host', 72),
#  ('music', 72),
#  ('went', 72),
#  ('lock', 72),
#  ('avail', 72),
#  ('expos', 71),
#  ('identifi', 71),
#  ('warn', 71),
#  ('dad', 71),
#  ('fear', 71),
#  ('demand', 71),
#  ('hit', 71),
#  ('bc', 71),
#  ('sick', 71),
#  ('drop', 71),
#  ('covidvaccin', 70),
#  ('doctor', 70),
#  ('speech', 70),
#  ('three', 70),
#  ('phone', 70),
#  ('prison', 70),
#  ('california', 70),
#  ('south', 70),
#  ('shes', 70),
#  ('gun', 70),
#  ('trend', 70),
#  ('senior', 69),
#  ('fraud', 69),
#  ('develop', 69),
#  ('shame', 69),
#  ('dear', 69),
#  ('sent', 69),
#  ('oday', 69),
#  ('crowd', 69),
#  ('resid', 68),
#  ('cpac', 68),
#  ('insid', 68),
#  ('info', 68),
#  ('ny', 68),
#  ('suspect', 68),
#  ('brave', 68),
#  ('rest', 68),
#  ('special', 68),
#  ('co', 68),
#  ('econom', 68),
#  ('asian', 68),
#  ('detail', 68),
#  ('respect', 68),
#  ('soon', 68),
#  ('john', 68),
#  ('eye', 68),
#  ('votebidenharri', 67),
#  ('wors', 67),
#  ('weve', 67),
#  ('prove', 67),
#  ('retweet', 67),
#  ('impact', 67),
#  ('attent', 67),
#  ('poor', 67),
#  ('gave', 67),
#  ('conserv', 67),
#  ('georgefloyd', 67),
#  ('wh', 67),
#  ('illeg', 67),
#  ('russian', 66),
#  ('worst', 66),
#  ('votebluetosaveamerica', 66),
#  ('drive', 66),
#  ('train', 66),
#  ('per', 66),
#  ('parent', 66),
#  ('ppl', 66),
#  ('honor', 66),
#  ('general', 66),
#  ('attempt', 66),
#  ('fda', 65),
#  ('conspiraci', 65),
#  ('measur', 65),
#  ('benefit', 65),
#  ('progress', 65),
#  ('critic', 65),
#  ('taken', 65),
#  ('domest', 65),
#  ('exact', 65),
#  ('challeng', 65),
#  ('dnc', 65),
#  ('lol', 65),
#  ('given', 65),
#  ('advis', 64),
#  ('build', 64),
#  ('area', 64),
#  ('worri', 64),
#  ('influenc', 64),
#  ('els', 64),
#  ('effort', 64),
#  ('absolut', 64),
#  ('funni', 64),
#  ('answer', 64),
#  ('pelosi', 64),
#  ('accus', 64),
#  ('candid', 64),
#  ('speakerpelosi', 64),
#  ('admit', 64),
#  ('selectionj', 64),
#  ('potenti', 64),
#  ('cancel', 64),
#  ('montevistalinect', 63),
#  ('administ', 63),
#  ('nc', 63),
#  ('votebiden', 63),
#  ('feb', 63),
#  ('count', 63),
#  ('particip', 63),
#  ('girl', 63),
#  ('destroy', 63),
#  ('univers', 63),
#  ('abl', 63),
#  ('az', 62),
#  ('remain', 62),
#  ('vs', 62),
#  ('rich', 62),
#  ('cours', 62),
#  ('sorri', 62),
#  ('later', 62),
#  ('guess', 62),
#  ('damn', 62),
#  ('violent', 62),
#  ('holdthemaccount', 61),
#  ('mt', 61),
#  ('mi', 61),
#  ('spent', 61),
#  ('g', 61),
#  ('father', 61),
#  ('role', 61),
#  ('australia', 61),
#  ('packag', 61),
#  ('hat', 61),
#  ('goe', 61),
#  ('major', 61),
#  ('despit', 61),
#  ('defend', 61),
#  ('mr', 61),
#  ('class', 61),
#  ('launch', 61),
#  ('pretoria', 60),
#  ('southernlinect', 60),
#  ('ia', 60),
#  ('caught', 60),
#  ('pfizer', 60),
#  ('jail', 60),
#  ('normal', 60),
#  ('repres', 60),
#  ('publish', 60),
#  ('men', 60),
#  ('futur', 60),
#  ('light', 60),
#  ('intellig', 60),
#  ('color', 60),
#  ('deserv', 60),
#  ('upon', 60),
#  ('drug', 59),
#  ('buy', 59),
#  ('teacher', 59),
#  ('joke', 59),
#  ('energi', 59),
#  ('opinion', 59),
#  ('heart', 59),
#  ('appear', 59),
#  ('fals', 59),
#  ('citizen', 59),
#  ('barron', 58),
#  ('voteear', 58),
#  ('mark', 58),
#  ('practic', 58),
#  ('sold', 58),
#  ('goplead', 58),
#  ('racial', 58),
#  ('nice', 58),
#  ('fall', 58),
#  ('exist', 58),
#  ('longer', 58),
#  ('leadership', 58),
#  ('wow', 58),
#  ('appoint', 58),
#  ('danger', 58),
#  ('serv', 58),
#  ('dumptrump', 57),
#  ('ms', 57),
#  ('distanc', 57),
#  ('beat', 57),
#  ('laurenboebert', 57),
#  ('civil', 57),
#  ('individu', 57),
#  ('havent', 57),
#  ('heard', 57),
#  ('blame', 57),
#  ('limit', 57),
#  ('mental', 57),
#  ('wish', 57),
#  ('forward', 57),
#  ('red', 57),
#  ('readi', 57),
#  ('podcast', 57),
#  ('associ', 57),
#  ('consid', 57),
#  ('getvaccin', 56),
#  ('held', 56),
#  ('r', 56),
#  ('wasnt', 56),
#  ('among', 56),
#  ('grate', 56),
#  ('incit', 56),
#  ('rt', 56),
#  ('four', 56),
#  ('term', 56),
#  ('aoc', 56),
#  ('l', 56),
#  ('mob', 56),
#  ('colleg', 56),
#  ('rd', 56),
#  ('usual', 56),
#  ('acbhear', 55),
#  ('twittercensorship', 55),
#  ('committe', 55),
#  ('russia', 55),
#  ('regist', 55),
#  ('prepar', 55),
#  ('ou', 55),
#  ('wednesday', 55),
#  ('liter', 55),
#  ('walk', 55),
#  ('decid', 55),
#  ('especi', 55),
#  ('staff', 55),
#  ('realiz', 55),
#  ('along', 55),
#  ('manag', 55),
#  ('song', 55),
#  ('piec', 55),
#  ('app', 55),
#  ('ak', 54),
#  ('nh', 54),
#  ('ks', 54),
#  ('leak', 54),
#  ('clinton', 54),
#  ('votehimout', 54),
#  ('brag', 54),
#  ('disgust', 54),
#  ('panel', 54),
#  ('georgia', 54),
#  ('introduc', 54),
#  ('tha', 54),
#  ('minor', 54),
#  ('small', 54),
#  ('add', 54),
#  ('tv', 54),
#  ('biggest', 54),
#  ('guidelin', 53),
#  ('votebluedownballot', 53),
#  ('economi', 53),
#  ('approach', 53),
#  ('barackobama', 53),
#  ('track', 53),
#  ('bomb', 53),
#  ('site', 53),
#  ('ohio', 53),
#  ('statement', 53),
#  ('moron', 53),
#  ('stimulus', 53),
#  ('nd', 53),
#  ('dollar', 53),
#  ('maskup', 53),
#  ('thousand', 53),
#  ('store', 53),
#  ('enjoy', 53),
#  ('senronjohnson', 52),
#  ('gov', 52),
#  ('bidencrimefamili', 52),
#  ('harm', 52),
#  ('request', 52),
#  ('beg', 52),
#  ('promis', 52),
#  ('entir', 52),
#  ('compar', 52),
#  ('traitor', 52),
#  ('quick', 52),
#  ('connect', 52),
#  ('cri', 52),
#  ('short', 52),
#  ('episod', 52),
#  ('putin', 51),
#  ('dream', 51),
#  ('qanon', 51),
#  ('stayhom', 51),
#  ('network', 51),
#  ('kelli', 51),
#  ('sens', 51),
#  ('scare', 51),
#  ('visit', 51),
#  ('intern', 51),
#  ('projectlincoln', 51),
#  ('assault', 51),
#  ('lift', 51),
#  ('wisconsin', 51),
#  ('wouldnt', 51),
#  ('shut', 51),
#  ('crisi', 51),
#  ('key', 51),
#  ('excit', 51),
#  ('base', 51),
#  ('pull', 51),
#  ('focus', 51),
#  ('young', 51),
#  ('institut', 51),
#  ('omthunkitsmind', 50),
#  ('retreat', 50),
#  ('corona', 50),
#  ('pennsylvania', 50),
#  ('distribut', 50),
#  ('desper', 50),
#  ('reduc', 50),
#  ('chao', 50),
#  ('own', 50),
#  ('steal', 50),
#  ('militari', 50),
#  ('michigan', 50),
#  ('regard', 50),
#  ('wayn', 50),
#  ...]

# %%
#Dictionary for token
wordfreq = {}
for token in df['token']:
    for i in range(len(token)):
        if token[i] not in wordfreq.keys():
            wordfreq[token[i]] = 1
        else:
            wordfreq[token[i]] += 1
            
sorted_token = sorted(wordfreq.items(), key=lambda kv: kv[1])
sorted_token.reverse()
sorted_token
# Out:
# [('covid', 4781),
#  ('trump', 4242),
#  ('biden', 2810),
#  ('joebiden', 1939),
#  ('blm', 1536),
#  ('people', 1336),
#  ('wearamask', 1327),
#  ('capitolriots', 1290),
#  ('us', 1102),
#  ('get', 992),
#  ('vaccine', 970),
#  ('dont', 914),
#  ('vote', 902),
#  ('new', 890),
#  ('like', 881),
#  ('black', 864),
#  ('know', 854),
#  ('one', 840),
#  ('please', 802),
#  ('election', 699),
#  ('mask', 689),
#  ('time', 635),
#  ('blacklivesmatter', 631),
#  ('capitol', 571),
#  ('still', 568),
#  ('hunterbiden', 552),
#  ('im', 549),
#  ('would', 531),
#  ('twitter', 520),
#  ('donaldtrump', 517),
#  ('fbi', 506),
#  ('see', 494),
#  ('police', 492),
#  ('need', 491),
#  ('president', 484),
#  ('via', 476),
#  ('gop', 476),
#  ('day', 468),
#  ('never', 463),
#  ('bidenharris', 462),
#  ('want', 439),
#  ('today', 438),
#  ('watch', 436),
#  ('white', 433),
#  ('seditionhunters', 418),
#  ('realdonaldtrump', 418),
#  ('good', 414),
#  ('cases', 413),
#  ('many', 413),
#  ('station', 411),
#  ('america', 408),
#  ('think', 398),
#  ('make', 397),
#  ('said', 395),
#  ('ump', 394),
#  ('even', 394),
#  ('go', 393),
#  ('first', 392),
#  ('say', 391),
#  ('going', 390),
#  ('joe', 387),
#  ('help', 383),
#  ('year', 377),
#  ('cant', 372),
#  ('news', 370),
#  ('got', 367),
#  ('health', 359),
#  ('maga', 358),
#  ('person', 351),
#  ('right', 345),
#  ('democrats', 339),
#  ('says', 339),
#  ('story', 333),
#  ('share', 332),
#  ('back', 319),
#  ('hunter', 318),
#  ('man', 317),
#  ('house', 313),
#  ('coronavirus', 310),
#  ('pandemic', 310),
#  ('th', 307),
#  ('kk', 304),
#  ('doesnt', 304),
#  ('years', 302),
#  ('support', 302),
#  ('another', 300),
#  ('family', 295),
#  ('take', 293),
#  ('trumps', 291),
#  ('nypost', 290),
#  ('vaccines', 289),
#  ('americans', 287),
#  ('also', 287),
#  ('state', 285),
#  ('town', 284),
#  ('last', 284),
#  ('world', 283),
#  ('stop', 280),
#  ('much', 279),
#  ('well', 279),
#  ('way', 278),
#  ('could', 277),
#  ('great', 276),
#  ('really', 274),
#  ('everyone', 273),
#  ('million', 272),
#  ('big', 272),
#  ('every', 271),
#  ('racism', 269),
#  ('let', 268),
#  ('must', 267),
#  ('keep', 266),
#  ('media', 266),
#  ('kamalaharris', 265),
#  ('texas', 265),
#  ('republicans', 263),
#  ('facebook', 262),
#  ('video', 260),
#  ('lives', 260),
#  ('hes', 259),
#  ('since', 258),
#  ('country', 258),
#  ('blacklivesmatte', 257),
#  ('across', 254),
#  ('racist', 254),
#  ('work', 251),
#  ('love', 250),
#  ('truth', 250),
#  ('masks', 249),
#  ('look', 249),
#  ('youre', 248),
#  ('lets', 246),
#  ('care', 246),
#  ('wear', 245),
#  ('face', 244),
#  ('made', 244),
#  ('thats', 243),
#  ('potus', 239),
#  ('nbc', 238),
#  ('son', 236),
#  ('relief', 236),
#  ('getting', 233),
#  ('ealdonaldtrump', 232),
#  ('american', 229),
#  ('may', 229),
#  ('johnson', 228),
#  ('thank', 226),
#  ('life', 225),
#  ('w', 225),
#  ('post', 223),
#  ('part', 223),
#  ('nothing', 218),
#  ('corruption', 217),
#  ('virus', 216),
#  ('bidens', 216),
#  ('bill', 213),
#  ('give', 213),
#  ('states', 211),
#  ('contact', 209),
#  ('next', 208),
#  ('iowa', 205),
#  ('hey', 205),
#  ('live', 205),
#  ('ukraine', 203),
#  ('wearing', 203),
#  ('thing', 201),
#  ('campaign', 200),
#  ('censorship', 199),
#  ('deaths', 199),
#  ('cnn', 198),
#  ('didnt', 198),
#  ('lies', 198),
#  ('hunterbidenemails', 197),
#  ('come', 196),
#  ('plan', 192),
#  ('msnbc', 192),
#  ('trying', 192),
#  ('departed', 190),
#  ('platforms', 190),
#  ('days', 190),
#  ('china', 189),
#  ('show', 189),
#  ('public', 189),
#  ('matter', 189),
#  ('check', 188),
#  ('around', 188),
#  ('voting', 187),
#  ('anyone', 187),
#  ('abc', 187),
#  ('better', 186),
#  ('u', 186),
#  ('continue', 185),
#  ('safe', 182),
#  ('real', 181),
#  ('hope', 181),
#  ('ever', 180),
#  ('use', 177),
#  ('burisma', 176),
#  ('money', 176),
#  ('vaccination', 175),
#  ('members', 175),
#  ('corrupt', 174),
#  ('anything', 174),
#  ('always', 174),
#  ('pm', 174),
#  ('home', 174),
#  ('believe', 174),
#  ('death', 174),
#  ('sure', 174),
#  ('county', 174),
#  ('vaccinated', 173),
#  ('two', 173),
#  ('long', 172),
#  ('isnt', 172),
#  ('bad', 172),
#  ('march', 172),
#  ('usa', 171),
#  ('dr', 171),
#  ('yet', 171),
#  ('obama', 170),
#  ('call', 170),
#  ('spread', 169),
#  ('wont', 169),
#  ('government', 169),
#  ('follow', 167),
#  ('find', 167),
#  ('week', 165),
#  ('stay', 164),
#  ('business', 163),
#  ('justice', 163),
#  ('free', 162),
#  ('left', 162),
#  ('remember', 161),
#  ('read', 160),
#  ('jan', 160),
#  ('others', 160),
#  ('social', 159),
#  ('end', 159),
#  ('history', 159),
#  ('senate', 158),
#  ('yall', 157),
#  ('office', 156),
#  ('lost', 155),
#  ('due', 155),
#  ('community', 155),
#  ('republican', 154),
#  ('called', 154),
#  ('someone', 153),
#  ('already', 153),
#  ('without', 152),
#  ('enroute', 151),
#  ('party', 151),
#  ('watching', 151),
#  ('positive', 151),
#  ('put', 151),
#  ('nbcnews', 149),
#  ('morning', 149),
#  ('congress', 148),
#  ('died', 148),
#  ('national', 148),
#  ('protect', 148),
#  ('old', 148),
#  ('youtube', 146),
#  ('tell', 146),
#  ('blackhistorymonth', 145),
#  ('forget', 145),
#  ('b', 145),
#  ('article', 144),
#  ('insurrection', 143),
#  ('away', 143),
#  ('emails', 142),
#  ('told', 142),
#  ('hall', 141),
#  ('best', 141),
#  ('breaking', 141),
#  ('hear', 140),
#  ('wants', 140),
#  ('yes', 140),
#  ('c', 140),
#  ('hard', 139),
#  ('gets', 138),
#  ('needs', 138),
#  ('heres', 138),
#  ('women', 138),
#  ('win', 137),
#  ('political', 137),
#  ('na', 137),
#  ('ago', 135),
#  ('debate', 135),
#  ('rally', 135),
#  ('bidenharristosaveamerica', 134),
#  ('hate', 134),
#  ('done', 134),
#  ('ive', 134),
#  ('theyre', 134),
#  ('trumpisalaughingstock', 132),
#  ('st', 132),
#  ('took', 132),
#  ('icecube', 131),
#  ('donald', 131),
#  ('case', 131),
#  ('politics', 130),
#  ('using', 130),
#  ('bidentownhall', 129),
#  ('working', 129),
#  ('top', 129),
#  ('foxnews', 129),
#  ('talk', 129),
#  ('k', 128),
#  ('enough', 128),
#  ('saying', 128),
#  ('seen', 127),
#  ('report', 126),
#  ('h', 125),
#  ('link', 125),
#  ('york', 124),
#  ('response', 124),
#  ('something', 124),
#  ('job', 124),
#  ('start', 123),
#  ('fact', 123),
#  ('wrong', 123),
#  ('actually', 122),
#  ('instead', 121),
#  ('almost', 121),
#  ('change', 121),
#  ('jack', 120),
#  ('arrested', 120),
#  ('friends', 119),
#  ('workers', 118),
#  ('india', 118),
#  ('lot', 118),
#  ('everything', 118),
#  ('weeks', 117),
#  ('shot', 117),
#  ('important', 116),
#  ('coming', 116),
#  ('found', 116),
#  ('law', 116),
#  ('talking', 115),
#  ('true', 115),
#  ('open', 115),
#  ('vp', 114),
#  ('voted', 114),
#  ('democrat', 114),
#  ('woman', 113),
#  ('received', 113),
#  ('little', 113),
#  ('officer', 112),
#  ('children', 112),
#  ('shit', 111),
#  ('update', 111),
#  ('name', 111),
#  ('f', 111),
#  ('making', 111),
#  ('things', 111),
#  ('ukrainian', 110),
#  ('witter', 110),
#  ('evidence', 110),
#  ('least', 110),
#  ('taking', 110),
#  ('months', 110),
#  ('attack', 110),
#  ('friday', 109),
#  ('oh', 109),
#  ('number', 109),
#  ('used', 109),
#  ('city', 108),
#  ('shows', 108),
#  ('pay', 108),
#  ('boycottnbc', 107),
#  ('early', 107),
#  ('wake', 107),
#  ('looking', 107),
#  ('thought', 107),
#  ('release', 106),
#  ('id', 106),
#  ('guy', 106),
#  ('january', 105),
#  ('test', 105),
#  ('lie', 105),
#  ('former', 105),
#  ('including', 105),
#  ('fight', 105),
#  ('far', 105),
#  ('group', 105),
#  ('try', 105),
#  ('school', 104),
#  ('questions', 104),
#  ('thanks', 104),
#  ('voteblue', 103),
#  ('mean', 103),
#  ('times', 103),
#  ('power', 103),
#  ('kids', 102),
#  ('gon', 102),
#  ('officers', 102),
#  ('afo', 101),
#  ('cape', 101),
#  ('trillion', 101),
#  ('tested', 101),
#  ('second', 101),
#  ('behind', 101),
#  ('night', 101),
#  ('proud', 101),
#  ('tomorrow', 100),
#  ('tonight', 100),
#  ('list', 100),
#  ('happy', 100),
#  ('point', 100),
#  ('happened', 100),
#  ('federal', 100),
#  ('ill', 100),
#  ('trumppence', 99),
#  ('florida', 99),
#  ('pa', 99),
#  ('whats', 99),
#  ('information', 99),
#  ('listen', 99),
#  ('freedom', 99),
#  ('full', 99),
#  ('latest', 99),
#  ('understand', 99),
#  ('flattenthecurve', 98),
#  ('administration', 98),
#  ('dead', 98),
#  ('blue', 98),
#  ('online', 97),
#  ('join', 97),
#  ('killed', 97),
#  ('data', 97),
#  ('month', 97),
#  ('save', 96),
#  ('whole', 96),
#  ('supporters', 96),
#  ('wi', 96),
#  ('trial', 96),
#  ('amazing', 96),
#  ('canada', 95),
#  ('reason', 95),
#  ('bts', 94),
#  ('medical', 94),
#  ('stand', 94),
#  ('knew', 94),
#  ('wanted', 94),
#  ('fo', 94),
#  ('n', 94),
#  ('breakingjury', 94),
#  ('daily', 93),
#  ('place', 93),
#  ('fake', 93),
#  ('crime', 93),
#  ('p', 93),
#  ('maybe', 93),
#  ('impeachment', 92),
#  ('war', 92),
#  ('means', 92),
#  ('february', 91),
#  ('safety', 91),
#  ('email', 91),
#  ('chief', 91),
#  ('whitehouse', 91),
#  ('theres', 91),
#  ('feel', 91),
#  ('less', 91),
#  ('security', 91),
#  ('united', 90),
#  ('resist', 90),
#  ('event', 90),
#  ('giving', 90),
#  ('race', 90),
#  ('dose', 89),
#  ('wait', 89),
#  ('ccp', 89),
#  ('calling', 89),
#  ('ask', 89),
#  ('shouldnt', 89),
#  ('dc', 88),
#  ('different', 88),
#  ('global', 88),
#  ('stopping', 87),
#  ('lying', 87),
#  ('votes', 87),
#  ('air', 87),
#  ('act', 87),
#  ('investigating', 86),
#  ('doses', 86),
#  ('maddow', 86),
#  ('antifa', 86),
#  ('known', 86),
#  ('trumpcovid', 85),
#  ('harris', 85),
#  ('numbers', 85),
#  ('arent', 85),
#  ('god', 85),
#  ('die', 85),
#  ('system', 85),
#  ('healthcare', 85),
#  ('fuck', 85),
#  ('facts', 85),
#  ('murder', 85),
#  ('court', 85),
#  ('voters', 84),
#  ('tax', 84),
#  ('fighting', 84),
#  ('democracy', 84),
#  ('speak', 84),
#  ('makes', 84),
#  ('donaldjtrumpjr', 83),
#  ('page', 83),
#  ('al', 83),
#  ('local', 83),
#  ('thursday', 83),
#  ('agree', 83),
#  ('message', 83),
#  ('george', 83),
#  ('northernlinect', 82),
#  ('tx', 82),
#  ('ga', 82),
#  ('riot', 82),
#  ('hours', 82),
#  ('hell', 82),
#  ('might', 82),
#  ('washington', 82),
#  ('lineupdateinboundt', 81),
#  ('running', 81),
#  ('probably', 81),
#  ('staysafe', 81),
#  ('released', 81),
#  ('run', 81),
#  ('leader', 81),
#  ('saw', 81),
#  ('kag', 80),
#  ('democratic', 80),
#  ('science', 80),
#  ('deal', 80),
#  ('tech', 80),
#  ('word', 80),
#  ('seems', 80),
#  ('censoring', 79),
#  ('fl', 79),
#  ('prosecutor', 79),
#  ('riots', 79),
#  ('reports', 79),
#  ('schools', 79),
#  ('bidenharrislandslide', 78),
#  ('vaccinations', 78),
#  ('patients', 78),
#  ('clear', 78),
#  ('liar', 78),
#  ('account', 78),
#  ('cdc', 78),
#  ('passed', 78),
#  ('millions', 78),
#  ('past', 78),
#  ('violence', 78),
#  ('guard', 77),
#  ('presidential', 77),
#  ('high', 77),
#  ('learn', 77),
#  ('townhall', 76),
#  ('become', 76),
#  ('head', 76),
#  ('imagine', 76),
#  ('ones', 76),
#  ('yo', 76),
#  ('rioters', 75),
#  ('control', 75),
#  ('team', 75),
#  ('stupid', 75),
#  ('likely', 75),
#  ('sign', 75),
#  ('finally', 75),
#  ('ca', 75),
#  ('uk', 75),
#  ('paid', 74),
#  ('arizona', 74),
#  ('study', 74),
#  ('friend', 74),
#  ('came', 74),
#  ('cover', 74),
#  ('criminal', 74),
#  ('press', 74),
#  ('insurrectionists', 73),
#  ('involved', 73),
#  ('play', 73),
#  ('together', 73),
#  ('book', 73),
#  ('knows', 73),
#  ('lgbtq', 73),
#  ('comes', 73),
#  ('nation', 73),
#  ('covidiots', 72),
#  ('reported', 72),
#  ('went', 72),
#  ('sad', 72),
#  ('officials', 72),
#  ('ok', 72),
#  ('single', 71),
#  ('music', 71),
#  ('families', 71),
#  ('access', 71),
#  ('set', 71),
#  ('bc', 71),
#  ('movement', 71),
#  ('yesterday', 71),
#  ('crazy', 70),
#  ('hospital', 70),
#  ('calls', 70),
#  ('wonder', 70),
#  ('rep', 70),
#  ('three', 70),
#  ('folks', 70),
#  ('south', 70),
#  ('trust', 70),
#  ('charged', 70),
#  ('shes', 70),
#  ('happen', 70),
#  ('created', 70),
#  ('excuses', 69),
#  ('records', 69),
#  ('testing', 69),
#  ('fraud', 69),
#  ('sent', 69),
#  ('hearing', 69),
#  ('close', 69),
#  ('sick', 69),
#  ('african', 69),
#  ('cpac', 68),
#  ('aids', 68),
#  ('info', 68),
#  ('total', 68),
#  ('ny', 68),
#  ('updated', 68),
#  ('hold', 68),
#  ('speech', 68),
#  ('co', 68),
#  ('peoples', 68),
#  ('lockdown', 68),
#  ('force', 68),
#  ('dear', 68),
#  ('available', 68),
#  ('soon', 68),
#  ('side', 68),
#  ('pass', 68),
#  ('continues', 68),
#  ('votebidenharris', 67),
#  ('brave', 67),
#  ('rest', 67),
#  ('worse', 67),
#  ('weve', 67),
#  ('following', 67),
#  ('protest', 67),
#  ('kill', 67),
#  ('attention', 67),
#  ('gave', 67),
#  ('wh', 67),
#  ('tweet', 67),
#  ('worst', 66),
#  ('votebluetosaveamerica', 66),
#  ('elections', 66),
#  ('leave', 66),
#  ('dad', 66),
#  ('risk', 66),
#  ('game', 66),
#  ('ppl', 66),
#  ('phone', 66),
#  ('california', 66),
#  ('action', 66),
#  ('ass', 66),
#  ('killing', 66),
#  ('investigation', 66),
#  ('according', 66),
#  ('problem', 66),
#  ('fda', 65),
#  ('hour', 65),
#  ('mandate', 65),
#  ('arrived', 65),
#  ('research', 65),
#  ('mans', 65),
#  ('effective', 65),
#  ('taken', 65),
#  ('todays', 65),
#  ('domestic', 65),
#  ('question', 65),
#  ('asked', 65),
#  ('dnc', 65),
#  ('protests', 65),
#  ('kind', 65),
#  ('meeting', 65),
#  ('looks', 65),
#  ('lol', 65),
#  ('issue', 65),
#  ('given', 65),
#  ('wins', 64),
#  ('remove', 64),
#  ('claims', 64),
#  ('students', 64),
#  ('rights', 64),
#  ('funny', 64),
#  ('speakerpelosi', 64),
#  ('living', 64),
#  ('selectionj', 64),
#  ('mind', 64),
#  ('losing', 64),
#  ('montevistalinect', 63),
#  ('nc', 63),
#  ('decisions', 63),
#  ('announced', 63),
#  ('votebiden', 63),
#  ('feb', 63),
#  ('lose', 63),
#  ('turn', 63),
#  ('education', 63),
#  ('special', 63),
#  ('move', 63),
#  ('per', 63),
#  ('lied', 63),
#  ('able', 63),
#  ('georgefloyd', 63),
#  ('protesters', 63),
#  ('ratings', 62),
#  ('az', 62),
#  ('billion', 62),
#  ('immunity', 62),
#  ('general', 62),
#  ('governor', 62),
#  ('else', 62),
#  ('vs', 62),
#  ('rules', 62),
#  ('sorry', 62),
#  ('later', 62),
#  ('holdthemaccountable', 61),
#  ('mt', 61),
#  ('mi', 61),
#  ('step', 61),
#  ('polls', 61),
#  ('spent', 61),
#  ('company', 61),
#  ('g', 61),
#  ('elected', 61),
#  ('fucking', 61),
#  ('poor', 61),
#  ('goes', 61),
#  ('bring', 61),
#  ('despite', 61),
#  ('mr', 61),
#  ('human', 61),
#  ('age', 61),
#  ('order', 61),
#  ('pretoria', 60),
#  ('southernlinect', 60),
#  ('facemask', 60),
#  ('ia', 60),
#  ('nursing', 60),
#  ('caught', 60),
#  ('actions', 60),
#  ('guys', 60),
#  ('restrictions', 60),
#  ('fired', 60),
#  ('parents', 60),
#  ('failure', 60),
#  ('dems', 60),
#  ('damn', 60),
#  ('helped', 59),
#  ('australia', 59),
#  ('rich', 59),
#  ('line', 59),
#  ('exactly', 59),
#  ('energy', 59),
#  ('terrorist', 59),
#  ('voteearly', 58),
#  ('residents', 58),
#  ('sold', 58),
#  ('nice', 58),
#  ('longer', 58),
#  ('leadership', 58),
#  ('businesses', 58),
#  ('helping', 58),
#  ('course', 58),
#  ('wow', 58),
#  ('prison', 58),
#  ('respect', 58),
#  ('judge', 58),
#  ('allowed', 58),
#  ('dumptrump', 57),
#  ('pfizer', 57),
#  ('ms', 57),
#  ('experts', 57),
#  ('laurenboebert', 57),
#  ('photo', 57),
#  ('havent', 57),
#  ('heard', 57),
#  ('economic', 57),
#  ('program', 57),
#  ('red', 57),
#  ('ready', 57),
#  ('john', 57),
#  ('hank', 57),
#  ('floyd', 57),
#  ('getvaccinated', 56),
#  ('russian', 56),
#  ('greene', 56),
#  ('receive', 56),
#  ('held', 56),
#  ('r', 56),
#  ('wasnt', 56),
#  ('among', 56),
#  ('policy', 56),
#  ('gopleader', 56),
#  ('communities', 56),
#  ('rt', 56),
#  ('four', 56),
#  ('threat', 56),
#  ('aoc', 56),
#  ('lead', 56),
#  ('l', 56),
#  ('possible', 56),
#  ('rate', 56),
#  ('hands', 56),
#  ('towards', 56),
#  ('idea', 56),
#  ('rd', 56),
#  ('twittercensorship', 55),
#  ('finds', 55),
#  ('send', 55),
#  ('civil', 55),
#  ('grateful', 55),
#  ('role', 55),
#  ('level', 55),
#  ('excuse', 55),
#  ('ou', 55),
#  ('wednesday', 55),
#  ('men', 55),
#  ('especially', 55),
#  ('staff', 55),
#  ('terrorists', 55),
#  ('light', 55),
#  ('along', 55),
#  ('class', 55),
#  ('cause', 55),
#  ('variants', 54),
#  ('ak', 54),
#  ('nh', 54),
#  ('ks', 54),
#  ('votehimout', 54),
#  ('russia', 54),
#  ('joebidens', 54),
#  ('countries', 54),
#  ('drive', 54),
#  ('waiting', 54),
#  ('tha', 54),
#  ('crimes', 54),
#  ('forward', 54),
#  ('speaking', 54),
#  ('small', 54),
#  ('seeing', 54),
#  ('tv', 54),
#  ('biggest', 54),
#  ('covidvaccine', 53),
#  ('guidelines', 53),
#  ('votebluedownballot', 53),
#  ('censored', 53),
#  ('benefit', 53),
#  ('alleged', 53),
#  ('shame', 53),
#  ('emergency', 53),
#  ('panel', 53),
#  ('georgia', 53),
#  ('stimulus', 53),
#  ('nd', 53),
#  ('package', 53),
#  ('words', 53),
#  ('maskup', 53),
#  ('oday', 53),
#  ('thinks', 53),
#  ('violent', 53),
#  ('beautiful', 53),
#  ('app', 53),
#  ('senronjohnson', 52),
#  ('increase', 52),
#  ('economy', 52),
#  ('gov', 52),
#  ('bidencrimefamily', 52),
#  ('conspiracy', 52),
#  ('barackobama', 52),
#  ('official', 52),
#  ('ohio', 52),
#  ('influence', 52),
#  ('tried', 52),
#  ('future', 52),
#  ('mob', 52),
#  ('fear', 52),
#  ('guess', 52),
#  ('videos', 52),
#  ('piece', 52),
#  ('barron', 51),
#  ('stayhome', 51),
#  ('kelly', 51),
#  ('charges', 51),
#  ('projectlincoln', 51),
#  ('needed', 51),
#  ('fire', 51),
#  ('wisconsin', 51),
#  ('wouldnt', 51),
#  ('literally', 51),
#  ('service', 51),
#  ('leaders', 51),
#  ('address', 51),
#  ('tweets', 51),
#  ('podcast', 51),
#  ('hit', 51),
#  ('add', 51),
#  ('young', 51),
#  ('started', 51),
#  ('omthunkitsmind', 50),
#  ('acbhearings', 50),
#  ('corona', 50),
#  ('pennsylvania', 50),
#  ('jail', 50),
#  ('sense', 50),
#  ('wayne', 50),
#  ('boy', 50),
#  ('member', 50),
#  ('brought', 50),
#  ('reminder', 50),
#  ('travel', 50),
#  ('youve', 50),
#  ('couldnt', 50),
#  ('sounds', 50),
#  ('retweet', 50),
#  ('showing', 50),
#  ('crisis', 50),
#  ('record', 50),
#  ('putting', 50),
#  ('pro', 50),
#  ('surprise', 50),
#  ('either', 50),
#  ('pretty', 50),
#  ('retreat', 49),
#  ('putin', 49),
#  ('doctors', 49),
#  ('taxes', 49),
#  ('related', 49),
#  ('illegal', 49),
#  ('idiot', 49),
#  ('leading', 49),
#  ('department', 49),
#  ('reality', 49),
#  ('gone', 49),
#  ('racial', 49),
#  ('washingtonpost', 49),
#  ('simple', 49),
#  ('mpd', 49),
#  ('heart', 49),
#  ('child', 49),
#  ('j', 49),
#  ('thinking', 49),
#  ('guilty', 49),
#  ('episode', 49),
#  ('slide', 48),
#  ('gopbetrayedamerica', 48),
#  ('hickenlooper', 48),
#  ('trumpcrimefamily', 48),
#  ('trumplandslidevictory', 48),
#  ('committee', 48),
#  ('chaos', 48),
#  ('confirmed', 48),
#  ('military', 48),
#  ('opinion', 48),
#  ('protecting', 48),
#  ('though', 48),
#  ('brings', 48),
#  ('source', 48),
#  ('rather', 48),
#  ('recent', 48),
#  ('cops', 48),
#  ('pelosi', 48),
#  ('current', 48),
#  ('taylor', 48),
#  ('outside', 48),
#  ('aint', 48),
#  ('bs', 48),
#  ('flu', 47),
#  ('oath', 47),
#  ('ahead', 47),
#  ('allegedly', 47),
#  ('seriously', 47),
#  ('senator', 47),
#  ('cunningham', 47),
#  ('publicly', 47),
#  ('fakenews', 47),
#  ('absolutely', 47),
#  ('debates', 47),
#  ('arrest', 47),
#  ('entire', 47),
#  ('key', 47),
#  ('discuss', 47),
#  ('false', 47),
#  ('several', 47),
#  ...]

# %% [markdown]
# # Modelling

# %%
df['stem_full'] = df['stem'].apply(lambda x: ' '.join(x))
df['token_full'] = df['token'].apply(lambda x: ' '.join(x))
df
# Out:
#                                                    tweet  label  \
# 0      silencing blm  priti patels antiprotest law  i...    BLM
# 1      illian johnbok nadiawhittomemp silly little wo...    BLM
# 2      errolwebber tell me would this be considered r...    BLM
# 3      apple wont let parler have an app but still ke...    BLM
# 4      malikaandrews wojespn can we get jlm trending ...    BLM
# ...                                                  ...    ...
# 26395  hey have brainwashed their base for generation...  Riots
# 26396  blackcat these neanderthals were there for blm...  Riots
# 26397  atrupar  dear jaketapper instead of airing tat...  Riots
# 26398  his is a bombshellmarjorie greene may have bee...  Riots
# 26399  omthunkitsmind lets talk about white supremacy...  Riots
#
#                                                    token  \
# 0      [silencing, blm, priti, patels, antiprotest, l...
# 1      [illian, johnbok, nadiawhittomemp, silly, litt...
# 2      [errolwebber, tell, would, considered, racistd...
# 3      [apple, wont, let, parler, app, still, keeps, ...
# 4      [malikaandrews, wojespn, get, jlm, trending, m...
# ...                                                  ...
# 26395  [hey, brainwashed, base, generations, im, stil...
# 26396  [blackcat, neanderthals, blm, blacklivesmatter...
# 26397  [atrupar, dear, jaketapper, instead, airing, t...
# 26398  [bombshellmarjorie, greene, may, genius, behin...
# 26399  [omthunkitsmind, lets, talk, white, supremacyc...
#
#                                                     stem  \
# 0      [silenc, blm, priti, patel, antiprotest, law, ...
# 1      [illian, johnbok, nadiawhittomemp, silli, litt...
# 2      [errolwebb, tell, would, consid, racistdo, peo...
# 3      [appl, wont, let, parler, app, still, keep, tw...
# 4      [malikaandrew, wojespn, get, jlm, trend, mayb,...
# ...                                                  ...
# 26395  [hey, brainwash, base, generat, im, still, pis...
# 26396  [blackcat, neanderth, blm, blacklivesmatt, cap...
# 26397  [atrupar, dear, jaketapp, instead, air, tatere...
# 26398  [bombshellmarjori, green, may, genius, behind,...
# 26399  [omthunkitsmind, let, talk, white, supremacyca...
#
#                                                stem_full  \
# 0      silenc blm priti patel antiprotest law iandunt...
# 1      illian johnbok nadiawhittomemp silli littl wok...
# 2      errolwebb tell would consid racistdo peopl sup...
# 3      appl wont let parler app still keep twitter al...
# 4      malikaandrew wojespn get jlm trend mayb nba pu...
# ...                                                  ...
# 26395  hey brainwash base generat im still piss trick...
# 26396  blackcat neanderth blm blacklivesmatt capitolriot
# 26397  atrupar dear jaketapp instead air tatereev tru...
# 26398  bombshellmarjori green may genius behind storm...
# 26399  omthunkitsmind let talk white supremacycapitol...
#
#                                               token_full
# 0      silencing blm priti patels antiprotest law ian...
# 1      illian johnbok nadiawhittomemp silly little wo...
# 2      errolwebber tell would considered racistdo peo...
# 3      apple wont let parler app still keeps twitter ...
# 4      malikaandrews wojespn get jlm trending maybe n...
# ...                                                  ...
# 26395  hey brainwashed base generations im still piss...
# 26396  blackcat neanderthals blm blacklivesmatter cap...
# 26397  atrupar dear jaketapper instead airing tateree...
# 26398  bombshellmarjorie greene may genius behind sto...
# 26399  omthunkitsmind lets talk white supremacycapito...
#
# [24329 rows x 6 columns]

# %% [markdown]
# Create a new column, concatenating all stemmed tweets

# %%
df['stem_full'] = df['stem'].apply(lambda x: ' '.join(x))

# %%
# y = List of associated labels to each tweet
y = [i for i in df['label']]

# %%
corpus = [i for i in df['stem_full']]
corpus_tok = [i for i in df['token_full']]

# %% [markdown]
# ### Internal performance check
#
# #### Use `train_test_split` with training dataset to check performance of models

# %%
# Count Vectorizer
from sklearn.feature_extraction.text import CountVectorizer

# TF-IDF
from sklearn.feature_extraction.text import TfidfTransformer

# Machine Learning; Training Naive Bayes (NB) classifier on training data.
from sklearn.naive_bayes import MultinomialNB

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %%
# We can write less code and run all the libraries in generating a model, by building a pipeline as follows:
from sklearn.pipeline import Pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(corpus, y, test_size=0.33, random_state=42)

clf_stem = Pipeline([('vect', CountVectorizer()), ('tfidf', TfidfTransformer()), ('clf', MultinomialNB())])
clf_stem = clf_stem.fit(X_train, y_train)

y_pred = clf_stem.predict(X_test)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred,target_names=tags))
# Out:
# accuracy 0.7797982314111347
#               precision    recall  f1-score   support
#
#          BLM       0.91      0.67      0.77      1631
#        Trump       0.79      0.68      0.73      1080
#        Biden       0.70      0.99      0.82      2851
#        Covid       0.95      0.76      0.84      1376
#        Riots       0.74      0.52      0.61      1091
#
#     accuracy                           0.78      8029
#    macro avg       0.82      0.72      0.76      8029
# weighted avg       0.80      0.78      0.77      8029

# %%
X_train_tok, X_test_tok, y_train_tok, y_test_tok = train_test_split(corpus_tok, y, test_size=0.33, random_state=42)

clf_tok = Pipeline([('vect', CountVectorizer()), ('tfidf', TfidfTransformer()), ('clf', MultinomialNB())])
clf_tok = clf_stem.fit(X_train_tok, y_train_tok)

y_pred_tok = clf_stem.predict(X_test_tok)

print('accuracy %s' % accuracy_score(y_pred_tok, y_test_tok))
print(classification_report(y_test_tok, y_pred_tok,target_names=tags))
# Out:
# accuracy 0.7865238510399801
#               precision    recall  f1-score   support
#
#          BLM       0.92      0.67      0.78      1631
#        Trump       0.79      0.70      0.74      1080
#        Biden       0.71      0.99      0.83      2851
#        Covid       0.95      0.78      0.86      1376
#        Riots       0.74      0.53      0.62      1091
#
#     accuracy                           0.79      8029
#    macro avg       0.82      0.73      0.76      8029
# weighted avg       0.81      0.79      0.78      8029

# %% [markdown]
# # Clean testing data
#
# Remember testing dataframe was set as `df2`

# %%
# Remove duplicates, other languages, remove punctuation again

# Drop NaN
df2.dropna(inplace=True)

# Drop Duplicates
df2.drop_duplicates(subset=['tweet'])

# Strip HTML
df2['tweet'] = df2['tweet'].apply(lambda x: strip_tags(x))

#Removes Punctuation
df2['tweet'] = df2['tweet'].apply(lambda x: re.sub('[!@#$:).;,?&]', '', str(x)))
#Removes hyperlinks
df2['tweet'] = df2['tweet'].apply(lambda x: re.sub(r'http\S+', '', str(x)))
#Remove newlines
df2['tweet'] = df2['tweet'].apply(lambda x: x.strip().replace('\\n', ''))
#Remove encoded characters
df2['tweet'] = df2['tweet'].apply(lambda x: re.sub(r'(\\x(.){2})', '', str(x)))
#Removes ' , ", and blank space
df2['tweet'] = df2['tweet'].apply(lambda x: x.replace("'", ""))
df2['tweet'] = df2['tweet'].apply(lambda x: x.replace('"', ""))
df2['tweet'] = df2['tweet'].apply(lambda x: x.strip())
#Remove escape charcters but keep emoji codes
df2['tweet'] = df2['tweet'].apply(lambda x: re.sub("\\\\", '', str(x)))
# Remove 'rt', retweet string. Remove newline character
df2['tweet'] = df2['tweet'].apply(lambda x: x.strip("rt ").replace('\n', ''))

# Remove other punctuation 
df2['tweet'] = df2['tweet'].apply(lambda x: ''.join(ch for ch in x if ch not in exclude))
df2['tweet'] = df2['tweet'].apply(lambda x: re.sub('[”’“1234567890]', '', str(x)))

# %% [markdown]
# ### Tokenize words

# %%
df2['token'] = df2['tweet'].apply(word_tokenize)

# %% [markdown]
# ### Remove Stop Words

# %%
df2['token'] = df2['token'].apply(lambda x:[word for word in x if word not in sw])

# %% [markdown]
# ### Create Stem Words from Token

# %%
df2['stem'] =  df2['token'].apply(lambda x: [stemmer.stem(i) for i in x])

# %% [markdown]
# ### Word Frequency

# %%
#Dictionary for token
wordfreq2 = {}
for token in df2['stem']:
    for i in range(len(token)):
        if token[i] not in wordfreq2.keys():
            wordfreq2[token[i]] = 1
        else:
            wordfreq2[token[i]] += 1
            
sorted_stem2 = sorted(wordfreq2.items(), key=lambda kv: kv[1])
sorted_stem2.reverse()
sorted_stem2
# Out:
# [('trump', 1411),
#  ('biden', 993),
#  ('covid', 727),
#  ('wearamask', 637),
#  ('joebiden', 452),
#  ('blacklivesmatt', 426),
#  ('mask', 355),
#  ('vote', 302),
#  ('die', 286),
#  ('get', 286),
#  ('capitolriot', 281),
#  ('peopl', 277),
#  ('like', 256),
#  ('black', 255),
#  ('us', 239),
#  ('elect', 232),
#  ('one', 231),
#  ('station', 225),
#  ('dont', 222),
#  ('day', 208),
#  ('de', 205),
#  ('ctzebra', 204),
#  ('donaldtrump', 196),
#  ('yo', 196),
#  ('say', 189),
#  ('vaccin', 188),
#  ('new', 185),
#  ('wear', 175),
#  ('know', 174),
#  ('usa', 172),
#  ('twitter', 167),
#  ('time', 166),
#  ('go', 161),
#  ('pleas', 157),
#  ('still', 151),
#  ('support', 147),
#  ('want', 139),
#  ('american', 135),
#  ('today', 134),
#  ('coronavirus', 133),
#  ('ump', 132),
#  ('would', 127),
#  ('make', 126),
#  ('capitol', 126),
#  ('see', 125),
#  ('presid', 123),
#  ('im', 123),
#  ('live', 121),
#  ('need', 120),
#  ('white', 120),
#  ('depart', 117),
#  ('la', 117),
#  ('look', 116),
#  ('realdonaldtrump', 115),
#  ('news', 114),
#  ('state', 114),
#  ('democrat', 113),
#  ('america', 112),
#  ('maga', 111),
#  ('bidenharri', 110),
#  ('good', 109),
#  ('gop', 109),
#  ('polic', 109),
#  ('republican', 106),
#  ('facebook', 106),
#  ('year', 106),
#  ('let', 106),
#  ('town', 105),
#  ('tri', 105),
#  ('joe', 104),
#  ('never', 104),
#  ('right', 104),
#  ('love', 103),
#  ('case', 102),
#  ('hunterbiden', 101),
#  ('lie', 101),
#  ('work', 100),
#  ('via', 96),
#  ('enrout', 95),
#  ('help', 90),
#  ('stop', 90),
#  ('even', 90),
#  ('post', 90),
#  ('ealdonaldtrump', 89),
#  ('follow', 89),
#  ('show', 88),
#  ('back', 88),
#  ('first', 87),
#  ('watch', 87),
#  ('son', 86),
#  ('keep', 86),
#  ('thank', 86),
#  ('hunter', 85),
#  ('take', 84),
#  ('think', 84),
#  ('care', 83),
#  ('blm', 83),
#  ('use', 82),
#  ('en', 81),
#  ('di', 81),
#  ('stori', 81),
#  ('th', 81),
#  ('fbi', 80),
#  ('corrupt', 80),
#  ('man', 80),
#  ('come', 80),
#  ('well', 79),
#  ('everyon', 77),
#  ('potus', 76),
#  ('impeach', 76),
#  ('report', 76),
#  ('got', 75),
#  ('doesnt', 75),
#  ('cant', 75),
#  ('mani', 75),
#  ('nypost', 73),
#  ('health', 73),
#  ('safe', 73),
#  ('il', 72),
#  ('famili', 72),
#  ('call', 72),
#  ('face', 72),
#  ('protect', 71),
#  ('great', 71),
#  ('last', 70),
#  ('blackhistorymonth', 70),
#  ('said', 69),
#  ('un', 68),
#  ('kk', 67),
#  ('email', 67),
#  ('march', 67),
#  ('public', 67),
#  ('histori', 67),
#  ('e', 66),
#  ('polit', 66),
#  ('link', 66),
#  ('check', 65),
#  ('death', 65),
#  ('et', 64),
#  ('offic', 64),
#  ('nurs', 63),
#  ('continu', 63),
#  ('nation', 63),
#  ('cape', 62),
#  ('le', 62),
#  ('realli', 62),
#  ('member', 62),
#  ('anoth', 62),
#  ('must', 61),
#  ('stay', 60),
#  ('plan', 59),
#  ('dr', 59),
#  ('life', 59),
#  ('virus', 58),
#  ('antitrump', 58),
#  ('donald', 58),
#  ('texa', 58),
#  ('w', 57),
#  ('week', 57),
#  ('ask', 56),
#  ('video', 56),
#  ('everi', 56),
#  ('pm', 56),
#  ('attack', 56),
#  ('china', 55),
#  ('home', 55),
#  ('made', 55),
#  ('pandem', 55),
#  ('women', 55),
#  ('friend', 55),
#  ('lineupdateinboundt', 54),
#  ('could', 54),
#  ('big', 54),
#  ('northernlinect', 53),
#  ('rp', 53),
#  ('obama', 53),
#  ('nbc', 53),
#  ('countri', 53),
#  ('matter', 53),
#  ('thing', 53),
#  ('may', 53),
#  ('cdc', 52),
#  ('hous', 52),
#  ('media', 52),
#  ('social', 52),
#  ('hope', 52),
#  ('tell', 52),
#  ('hospit', 51),
#  ('share', 51),
#  ('account', 51),
#  ('talk', 51),
#  ('happi', 51),
#  ('ukrain', 50),
#  ('part', 50),
#  ('sinc', 50),
#  ('communiti', 50),
#  ('win', 50),
#  ('read', 50),
#  ('month', 50),
#  ('hes', 49),
#  ('your', 49),
#  ('parti', 49),
#  ('kill', 49),
#  ('mean', 48),
#  ('yet', 48),
#  ('morn', 48),
#  ('long', 48),
#  ('busi', 48),
#  ('believ', 48),
#  ('put', 48),
#  ('justic', 48),
#  ('that', 48),
#  ('macron', 47),
#  ('hunterbidenemail', 47),
#  ('find', 47),
#  ('ue', 47),
#  ('witter', 47),
#  ('much', 47),
#  ('boy', 47),
#  ('southernlinect', 46),
#  ('whitehous', 46),
#  ('u', 46),
#  ('next', 46),
#  ('also', 46),
#  ('million', 46),
#  ('start', 45),
#  ('youtub', 45),
#  ('chang', 45),
#  ('protest', 45),
#  ('der', 44),
#  ('voteblu', 44),
#  ('deal', 44),
#  ('person', 44),
#  ('noth', 44),
#  ('proud', 44),
#  ('montevistalinect', 43),
#  ('infect', 43),
#  ('articl', 43),
#  ('feel', 43),
#  ('ca', 43),
#  ('happen', 43),
#  ('hey', 43),
#  ('beirut', 42),
#  ('truth', 42),
#  ('al', 42),
#  ('kamalaharri', 42),
#  ('told', 42),
#  ('record', 42),
#  ('insurrect', 42),
#  ('und', 41),
#  ('covidvaccin', 41),
#  ('st', 41),
#  ('better', 41),
#  ('spread', 41),
#  ('nice', 41),
#  ('florida', 41),
#  ('ny', 41),
#  ('way', 41),
#  ('fight', 41),
#  ('racism', 41),
#  ('‘', 40),
#  ('poll', 40),
#  ('uselect', 40),
#  ('campaign', 40),
#  ('wait', 40),
#  ('hear', 40),
#  ('ive', 40),
#  ('two', 40),
#  ('guy', 40),
#  ('anyon', 40),
#  ('yall', 40),
#  ('pretoria', 39),
#  ('per', 39),
#  ('senat', 39),
#  ('wont', 39),
#  ('give', 39),
#  ('arrest', 39),
#  ('charg', 39),
#  ('racist', 39),
#  ('hand', 39),
#  ('number', 38),
#  ('cnn', 38),
#  ('secur', 38),
#  ('europ', 38),
#  ('epstein', 38),
#  ('excus', 38),
#  ('beauti', 38),
#  ('around', 38),
#  ('retreat', 37),
#  ('del', 37),
#  ('posit', 37),
#  ('riot', 37),
#  ('design', 37),
#  ('shot', 37),
#  ('na', 37),
#  ('world', 37),
#  ('tweet', 37),
#  ('staysaf', 36),
#  ('les', 36),
#  ('voter', 36),
#  ('lose', 36),
#  ('congress', 36),
#  ('center', 36),
#  ('ago', 36),
#  ('away', 36),
#  ('sign', 36),
#  ('pass', 35),
#  ('debat', 35),
#  ('best', 35),
#  ('scienc', 35),
#  ('hall', 35),
#  ('seem', 35),
#  ('open', 35),
#  ('hate', 35),
#  ('without', 35),
#  ('import', 35),
#  ('inform', 35),
#  ('censorship', 34),
#  ('test', 34),
#  ('des', 34),
#  ('break', 34),
#  ('hold', 34),
#  ('actual', 34),
#  ('dem', 34),
#  ('someth', 34),
#  ('real', 34),
#  ('ding', 34),
#  ('bad', 34),
#  ('other', 34),
#  ('woman', 34),
#  ('action', 34),
#  ('van', 33),
#  ('nbcnew', 33),
#  ('els', 33),
#  ('mayb', 33),
#  ('god', 33),
#  ('someon', 33),
#  ('msnbc', 33),
#  ('save', 33),
#  ('job', 33),
#  ('isnt', 33),
#  ('rememb', 33),
#  ('join', 33),
#  ('washyourhand', 32),
#  ('burisma', 32),
#  ('dumptrump', 32),
#  ('mind', 32),
#  ('iowa', 32),
#  ('investig', 32),
#  ('confirm', 32),
#  ('storm', 32),
#  ('ever', 32),
#  ('sure', 32),
#  ('power', 32),
#  ('forc', 32),
#  ('end', 32),
#  ('listen', 32),
#  ('point', 32),
#  ('top', 32),
#  ('data', 32),
#  ('stayhom', 31),
#  ('run', 31),
#  ('done', 31),
#  ('fire', 31),
#  ('word', 31),
#  ('move', 31),
#  ('releas', 31),
#  ('lost', 31),
#  ('children', 31),
#  ('name', 31),
#  ('worri', 30),
#  ('el', 30),
#  ('non', 30),
#  ('alreadi', 30),
#  ('allow', 30),
#  ('yes', 30),
#  ('democraci', 30),
#  ('c', 30),
#  ('school', 30),
#  ('found', 30),
#  ('music', 30),
#  ('left', 30),
#  ('fulli', 30),
#  ('movement', 30),
#  ('york', 30),
#  ('men', 30),
#  ('educ', 30),
#  ('everyth', 30),
#  ('group', 30),
#  ('indianamerican', 29),
#  ('che', 29),
#  ('het', 29),
#  ('que', 29),
#  ('healthcar', 29),
#  ('censor', 29),
#  ('du', 29),
#  ('polici', 29),
#  ('clear', 29),
#  ('alway', 29),
#  ('question', 29),
#  ('art', 29),
#  ('medic', 29),
#  ('wonder', 29),
#  ('reason', 29),
#  ('seen', 29),
#  ('enough', 29),
#  ('place', 29),
#  ('fake', 28),
#  ('close', 28),
#  ('uk', 28),
#  ('kind', 28),
#  ('celebr', 28),
#  ('ignor', 28),
#  ('offici', 28),
#  ('night', 28),
#  ('ralli', 28),
#  ('murder', 28),
#  ('forget', 28),
#  ('los', 27),
#  ('updat', 27),
#  ('à', 27),
#  ('con', 27),
#  ('presidenti', 27),
#  ('respons', 27),
#  ('queen', 27),
#  ('citi', 27),
#  ('remind', 27),
#  ('page', 27),
#  ('littl', 27),
#  ('order', 27),
#  ('se', 27),
#  ('sit', 27),
#  ('onlin', 27),
#  ('stand', 27),
#  ('law', 27),
#  ('dead', 27),
#  ('getvaccin', 26),
#  ('sur', 26),
#  ('trumpliedkdi', 26),
#  ('fucktrumpsshi', 26),
#  ('shitler', 26),
#  ('murdererinchief', 26),
#  ('negligenthomicid', 26),
#  ('operationmaga', 26),
#  ('ftrump', 26),
#  ('vetsforsci', 26),
#  ('makeamericaunitedagain', 26),
#  ('rate', 26),
#  ('tech', 26),
#  ('cours', 26),
#  ('vp', 26),
#  ('didnt', 26),
#  ('problem', 26),
#  ('jan', 26),
#  ('parent', 26),
#  ('enjoy', 26),
#  ('facemask', 25),
#  ('flattenthecurv', 25),
#  ('een', 25),
#  ('ukrainian', 25),
#  ('donaldjtrump', 25),
#  ('trumpcovid', 25),
#  ('understand', 25),
#  ('pour', 25),
#  ('fact', 25),
#  ('act', 25),
#  ('indian', 25),
#  ('counti', 25),
#  ('folk', 25),
#  ('turn', 25),
#  ('least', 25),
#  ('behind', 25),
#  ('reveal', 25),
#  ('hell', 25),
#  ('fuck', 25),
#  ('oper', 25),
#  ('h', 25),
#  ('gon', 25),
#  ('interest', 25),
#  ('lot', 25),
#  ('daili', 25),
#  ('fraud', 25),
#  ('learn', 25),
#  ('avail', 25),
#  ('govern', 25),
#  ('seditionhunt', 24),
#  ('climateact', 24),
#  ('abc', 24),
#  ('ein', 24),
#  ('covidiot', 24),
#  ('sourc', 24),
#  ('object', 24),
#  ('firechucktodd', 24),
#  ('aid', 24),
#  ('oh', 24),
#  ('jesuit', 24),
#  ('jack', 24),
#  ('theyr', 24),
#  ('op', 24),
#  ('rn', 24),
#  ('bring', 24),
#  ('true', 24),
#  ('oday', 24),
#  ('liber', 24),
#  ('ha', 24),
#  ('issu', 24),
#  ('harri', 24),
#  ('possibl', 24),
#  ('court', 24),
#  ('kid', 24),
#  ('anyth', 24),
#  ('washington', 24),
#  ('met', 24),
#  ('race', 24),
#  ('creat', 24),
#  ('instead', 24),
#  ('mental', 24),
#  ('worker', 24),
#  ('assault', 24),
#  ('especi', 24),
#  ('peac', 24),
#  ('servic', 24),
#  ('tuesdayvib', 23),
#  ('hed', 23),
#  ('mandat', 23),
#  ('trumpisalos', 23),
#  ('play', 23),
#  ('tax', 23),
#  ('barron', 23),
#  ('program', 23),
#  ('administr', 23),
#  ('green', 23),
#  ('far', 23),
#  ('wh', 23),
#  ('money', 23),
#  ('rt', 23),
#  ('there', 23),
#  ('ill', 23),
#  ('california', 23),
#  ('sta', 23),
#  ('practic', 23),
#  ('insurrectionist', 23),
#  ('soon', 23),
#  ('contact', 23),
#  ('human', 23),
#  ('destroy', 23),
#  ('f', 23),
#  ('hour', 23),
#  ('democraticparti', 22),
#  ('prevent', 22),
#  ('è', 22),
#  ('dan', 22),
#  ('fail', 22),
#  ('trumpcrimefamili', 22),
#  ('buy', 22),
#  ('requir', 22),
#  ('shouldnt', 22),
#  ('est', 22),
#  ('lead', 22),
#  ('colleagu', 22),
#  ('here', 22),
#  ('distanc', 22),
#  ('former', 22),
#  ('plus', 22),
#  ('trend', 22),
#  ('blame', 22),
#  ('wouldnt', 22),
#  ('total', 22),
#  ('shit', 22),
#  ('n', 22),
#  ('side', 22),
#  ('increas', 22),
#  ('becom', 22),
#  ('street', 22),
#  ('crime', 22),
#  ('absolut', 22),
#  ('miss', 22),
#  ('game', 22),
#  ('b', 22),
#  ('capetowntrain', 21),
#  ('joebidenjoebidenkamalaharri', 21),
#  ('katyayan', 21),
#  ('tx', 21),
#  ('zijn', 21),
#  ('hasnt', 21),
#  ('rule', 21),
#  ('restrict', 21),
#  ('hi', 21),
#  ('k', 21),
#  ('pelosi', 21),
#  ('stupid', 21),
#  ('donaldjtrumpjr', 21),
#  ('vs', 21),
#  ('wash', 21),
#  ('high', 21),
#  ('surpris', 21),
#  ('cover', 21),
#  ('das', 21),
#  ('tha', 21),
#  ('second', 21),
#  ('old', 21),
#  ('wish', 21),
#  ('januari', 21),
#  ('tv', 21),
#  ('retweet', 21),
#  ('foxnew', 21),
#  ('wow', 21),
#  ('direct', 21),
#  ('leav', 21),
#  ('thought', 21),
#  ('color', 21),
#  ('citizen', 21),
#  ('modili', 20),
#  ('von', 20),
#  ('normal', 20),
#  ('den', 20),
#  ('due', 20),
#  ('wrong', 20),
#  ('safeti', 20),
#  ('sorri', 20),
#  ('block', 20),
#  ('push', 20),
#  ('governor', 20),
#  ('rioter', 20),
#  ('survey', 20),
#  ('what', 20),
#  ('georg', 20),
#  ('activ', 20),
#  ('local', 20),
#  ('whole', 20),
#  ('excit', 20),
#  ('free', 20),
#  ('full', 20),
#  ('resist', 20),
#  ('p', 20),
#  ('accept', 20),
#  ('student', 20),
#  ('nyc', 20),
#  ('shuttleservic', 19),
#  ('np', 19),
#  ('spring', 19),
#  ('über', 19),
#  ('hoax', 19),
#  ('zu', 19),
#  ('ok', 19),
#  ('walk', 19),
#  ('gun', 19),
#  ('crimin', 19),
#  ('qanon', 19),
#  ('fish', 19),
#  ('manag', 19),
#  ('arriv', 19),
#  ('scandal', 19),
#  ('phone', 19),
#  ('trial', 19),
#  ('reduc', 19),
#  ('respect', 19),
#  ('team', 19),
#  ('decis', 19),
#  ('yesterday', 19),
#  ('leader', 19),
#  ('latest', 19),
#  ('profil', 19),
#  ('tonight', 19),
#  ('saturday', 19),
#  ('amaz', 19),
#  ('hard', 19),
#  ('info', 19),
#  ('divers', 19),
#  ('child', 19),
#  ('cop', 19),
#  ('demand', 19),
#  ('hoek', 18),
#  ('varindersingh', 18),
#  ('beg', 18),
#  ('borisjohnson', 18),
#  ('patient', 18),
#  ('ne', 18),
#  ('qui', 18),
#  ('wake', 18),
#  ('della', 18),
#  ('pas', 18),
#  ('voor', 18),
#  ('corona', 18),
#  ('für', 18),
#  ('refus', 18),
#  ('solut', 18),
#  ('kag', 18),
#  ('russia', 18),
#  ('politician', 18),
#  ('icecub', 18),
#  ('result', 18),
#  ('italia', 18),
#  ('ivankatrump', 18),
#  ('clinton', 18),
#  ('da', 18),
#  ('sound', 18),
#  ('ft', 18),
#  ('wtf', 18),
#  ('sens', 18),
#  ('air', 18),
#  ('evid', 18),
#  ('organ', 18),
#  ('funni', 18),
#  ('control', 18),
#  ('l', 18),
#  ('remov', 18),
#  ('almost', 18),
#  ('step', 18),
#  ('extrem', 18),
#  ('agre', 18),
#  ('hat', 18),
#  ('book', 18),
#  ('discuss', 18),
#  ('speak', 18),
#  ('past', 18),
#  ('meet', 18),
#  ('tomorrow', 18),
#  ('comment', 18),
#  ('front', 18),
#  ('shop', 18),
#  ('singl', 18),
#  ('system', 18),
#  ('natur', 18),
#  ('gregabbotttx', 17),
#  ('guard', 17),
#  ('nowplayingonsplashfm', 17),
#  ('nose', 17),
#  ('nicht', 17),
#  ('genius', 17),
#  ('terrorist', 17),
#  ('giuliani', 17),
#  ('head', 17),
#  ('boycottnbc', 17),
#  ('hunterbidenlaptop', 17),
#  ('flotus', 17),
#  ('je', 17),
#  ('outsid', 17),
#  ('pay', 17),
#  ('associ', 17),
#  ('wo', 17),
#  ('sad', 17),
#  ('idiot', 17),
#  ('g', 17),
#  ('ass', 17),
#  ('tuesday', 17),
#  ('meanwhil', 17),
#  ('accord', 17),
#  ('terror', 17),
#  ('risk', 17),
#  ('lawyer', 17),
#  ('favorit', 17),
#  ('germani', 17),
#  ('cancel', 17),
#  ('fo', 17),
#  ('arent', 17),
#  ('known', 17),
#  ('differ', 17),
#  ('less', 17),
#  ('song', 17),
#  ('jacobblak', 17),
#  ('across', 17),
#  ('honor', 17),
#  ('pa', 17),
#  ('danielprud', 17),
#  ('summer', 17),
#  ('freedom', 17),
#  ('guess', 17),
#  ('event', 17),
#  ('appointe', 16),
#  ('cdcgov', 16),
#  ('guidelin', 16),
#  ('socialdist', 16),
#  ('traitor', 16),
#  ('wcovidtr🤡mp', 16),
#  ('obvious', 16),
#  ('artikel', 16),
#  ('treason', 16),
#  ('newyorkpost', 16),
#  ('amyconeybarrett', 16),
#  ('putin', 16),
#  ('bidentownhal', 16),
#  ('doctor', 16),
#  ('engin', 16),
#  ('candid', 16),
#  ('tie', 16),
#  ('approach', 16),
#  ('expect', 16),
#  ('defend', 16),
#  ('receiv', 16),
#  ('si', 16),
#  ('went', 16),
#  ('interview', 16),
#  ('build', 16),
#  ('monday', 16),
#  ('sever', 16),
#  ('deep', 16),
#  ('rest', 16),
#  ('effect', 16),
#  ('view', 16),
#  ('serv', 16),
#  ('app', 16),
#  ('prosecutor', 16),
#  ('activist', 16),
#  ('mother', 16),
#  ('steal', 16),
#  ('set', 16),
#  ('bombshellmarjori', 15),
#  ('lineupdateoutboundt', 15),
#  ('wearadamnmask', 15),
#  ('nj', 15),
#  ('pienaarspoorttrain', 15),
#  ('sunak', 15),
#  ('remot', 15),
#  ('san', 15),
#  ('beat', 15),
#  ('jail', 15),
#  ('itali', 15),
#  ('dat', 15),
#  ('lockdown', 15),
#  ('lock', 15),
#  ('near', 15),
#  ('store', 15),
#  ('crowd', 15),
#  ('suppress', 15),
#  ('liar', 15),
#  ('infecti', 15),
#  ('censur', 15),
#  ('selfi', 15),
#  ('england', 15),
#  ('economi', 15),
#  ('twittercensorship', 15),
#  ('mr', 15),
#  ('goplead', 15),
#  ('idea', 15),
#  ('messag', 15),
#  ('claim', 15),
#  ('line', 15),
#  ('explain', 15),
#  ('proudboy', 15),
#  ('caus', 15),
#  ('shed', 15),
#  ('cut', 15),
#  ('involv', 15),
#  ('war', 15),
#  ('donat', 15),
#  ('probabl', 15),
#  ('antifa', 15),
#  ('delet', 15),
#  ('lol', 15),
#  ('desper', 15),
#  ('complet', 15),
#  ('sick', 15),
#  ('wors', 15),
#  ('knew', 15),
#  ('john', 15),
#  ('forward', 15),
#  ('mom', 15),
#  ('podcast', 15),
#  ('nd', 15),
#  ('episod', 15),
#  ('gave', 15),
#  ('senategop', 15),
#  ('abus', 15),
#  ('wednesday', 15),
#  ('heart', 15),
#  ('projectlincoln', 15),
#  ('moment', 15),
#  ('racial', 15),
#  ('final', 15),
#  ('violent', 15),
#  ('gopcomplicittraitor', 14),
#  ('berailsma', 14),
#  ('realfloodbaba', 14),
#  ('breakfastjam', 14),
#  ('indoor', 14),
#  ('med', 14),
#  ('mabopanetrain', 14),
#  ('amber', 14),
#  ('ftse', 14),
#  ('commerci', 14),
#  ('photo', 14),
#  ('lil', 14),
#  ('communic', 14),
#  ('dad', 14),
#  ('wasnt', 14),
#  ('restaur', 14),
#  ('visit', 14),
#  ('hillaryclinton', 14),
#  ('brave', 14),
#  ('figlio', 14),
#  ('una', 14),
#  ('slow', 14),
#  ('tbt', 14),
#  ('trumpral', 14),
#  ('fiverr', 14),
#  ('entir', 14),
#  ('christian', 14),
#  ('fall', 14),
#  ('su', 14),
#  ('dei', 14),
#  ('repres', 14),
#  ('role', 14),
#  ('mouth', 14),
#  ('chanc', 14),
#  ('jr', 14),
#  ('challeng', 14),
#  ('father', 14),
#  ('imagin', 14),
#  ('choic', 14),
#  ('add', 14),
#  ('send', 14),
#  ('nytim', 14),
#  ('illeg', 14),
#  ('earli', 14),
#  ('might', 14),
#  ('ou', 14),
#  ('dog', 14),
#  ('floyd', 14),
#  ('bc', 14),
#  ('blue', 14),
#  ('grand', 14),
#  ('wast', 14),
#  ('sue', 14),
#  ('violenc', 14),
#  ('heard', 14),
#  ('platform', 14),
#  ('voic', 14),
#  ('common', 14),
#  ('ahmaud', 14),
#  ('took', 14),
#  ('friday', 14),
#  ('legal', 14),
#  ('klein', 13),
#  ('maskup', 13),
#  ('cna', 13),
#  ('weekend', 13),
#  ('april', 13),
#  ('dose', 13),
#  ('handmad', 13),
#  ('princeharri', 13),
#  ('princewilliam', 13),
#  ('lebanon', 13),
#  ('footbal', 13),
#  ('cad', 13),
#  ('daydesign', 13),
#  ('gig', 13),
#  ('freelanc', 13),
#  ('kitchen', 13),
#  ('commercialkitchendesignkitchenlayout', 13),
#  ('robert', 13),
#  ('connect', 13),
#  ('fauci', 13),
#  ('abl', 13),
#  ('americanpeopl', 13),
#  ('maar', 13),
#  ('mit', 13),
#  ('critic', 13),
#  ('au', 13),
#  ('er', 13),
#  ('trumpcovidhoax', 13),
#  ('north', 13),
#  ('es', 13),
#  ('wing', 13),
#  ('major', 13),
#  ('trumppenc', 13),
#  ('ice', 13),
#  ('socialdistanc', 13),
#  ('conspiraci', 13),
#  ('loro', 13),
#  ('anch', 13),
#  ('erictrump', 13),
#  ('gopchairwoman', 13),
#  ('fashion', 13),
#  ('intern', 13),
#  ('conserv', 13),
#  ('liter', 13),
#  ('experi', 13),
#  ('pro', 13),
#  ('director', 13),
#  ('dream', 13),
#  ('smart', 13),
#  ('unit', 13),
#  ('respond', 13),
#  ('r', 13),
#  ('offer', 13),
#  ('expos', 13),
#  ('readi', 13),
#  ('deni', 13),
#  ('key', 13),
#  ('fear', 13),
#  ('brain', 13),
#  ('hank', 13),
#  ('v', 13),
#  ('rais', 13),
#  ('futur', 13),
#  ('girl', 13),
#  ('alli', 13),
#  ('relat', 13),
#  ('eat', 13),
#  ...]

# %%
#Dictionary for token
wordfreq2_tok = {}
for token in df2['token']:
    for i in range(len(token)):
        if token[i] not in wordfreq2_tok.keys():
            wordfreq2_tok[token[i]] = 1
        else:
            wordfreq2_tok[token[i]] += 1
            
sorted_token = sorted(wordfreq2_tok.items(), key=lambda kv: kv[1])
sorted_token.reverse()
sorted_token
# Out:
# [('trump', 1348),
#  ('biden', 949),
#  ('covid', 725),
#  ('wearamask', 637),
#  ('joebiden', 439),
#  ('blacklivesmatter', 283),
#  ('capitolriots', 279),
#  ('people', 271),
#  ('mask', 250),
#  ('black', 242),
#  ('us', 239),
#  ('like', 237),
#  ('station', 222),
#  ('dont', 222),
#  ('one', 213),
#  ('died', 211),
#  ('de', 205),
#  ('vote', 205),
#  ('ctzebra', 204),
#  ('get', 203),
#  ('yo', 196),
#  ('donaldtrump', 195),
#  ('new', 185),
#  ('election', 180),
#  ('usa', 172),
#  ('twitter', 165),
#  ('day', 154),
#  ('please', 153),
#  ('still', 151),
#  ('know', 148),
#  ('blacklivesmatte', 143),
#  ('coronavirus', 133),
#  ('time', 131),
#  ('ump', 127),
#  ('would', 127),
#  ('today', 127),
#  ('capitol', 126),
#  ('im', 122),
#  ('white', 118),
#  ('la', 117),
#  ('realdonaldtrump', 115),
#  ('news', 114),
#  ('president', 112),
#  ('see', 112),
#  ('bidenharris', 110),
#  ('maga', 110),
#  ('gop', 108),
#  ('facebook', 106),
#  ('police', 106),
#  ('america', 106),
#  ('town', 105),
#  ('wear', 104),
#  ('joe', 104),
#  ('never', 104),
#  ('good', 103),
#  ('departed', 99),
#  ('want', 99),
#  ('masks', 98),
#  ('hunterbiden', 96),
#  ('via', 96),
#  ('enroute', 95),
#  ('ealdonaldtrump', 89),
#  ('go', 89),
#  ('first', 87),
#  ('right', 87),
#  ('need', 86),
#  ('even', 84),
#  ('americans', 83),
#  ('blm', 83),
#  ('en', 81),
#  ('di', 81),
#  ('son', 81),
#  ('say', 81),
#  ('th', 81),
#  ('fbi', 80),
#  ('back', 80),
#  ('make', 79),
#  ('support', 79),
#  ('cases', 76),
#  ('potus', 76),
#  ('well', 76),
#  ('vaccinated', 75),
#  ('hunter', 75),
#  ('got', 75),
#  ('doesnt', 75),
#  ('cant', 75),
#  ('everyone', 75),
#  ('democrats', 74),
#  ('many', 74),
#  ('nypost', 73),
#  ('says', 73),
#  ('health', 73),
#  ('going', 72),
#  ('state', 72),
#  ('wearing', 71),
#  ('keep', 71),
#  ('great', 71),
#  ('post', 71),
#  ('il', 70),
#  ('safe', 70),
#  ('blackhistorymonth', 70),
#  ('last', 69),
#  ('said', 69),
#  ('think', 69),
#  ('die', 68),
#  ('help', 68),
#  ('kk', 67),
#  ('story', 67),
#  ('history', 67),
#  ('e', 66),
#  ('vaccine', 66),
#  ('care', 66),
#  ('un', 65),
#  ('face', 65),
#  ('et', 64),
#  ('family', 64),
#  ('watch', 64),
#  ('trumps', 63),
#  ('republicans', 63),
#  ('cape', 62),
#  ('le', 62),
#  ('man', 62),
#  ('really', 62),
#  ('march', 62),
#  ('another', 62),
#  ('take', 61),
#  ('must', 61),
#  ('love', 60),
#  ('work', 60),
#  ('follow', 60),
#  ('lies', 59),
#  ('dr', 59),
#  ('antitrump', 58),
#  ('voting', 58),
#  ('texas', 58),
#  ('life', 58),
#  ('stay', 58),
#  ('thank', 58),
#  ('year', 58),
#  ('impeachment', 57),
#  ('donald', 57),
#  ('lets', 57),
#  ('lives', 57),
#  ('w', 57),
#  ('trying', 57),
#  ('virus', 56),
#  ('show', 56),
#  ('every', 56),
#  ('pm', 56),
#  ('made', 55),
#  ('look', 55),
#  ('lineupdateinboundt', 54),
#  ('could', 54),
#  ('days', 54),
#  ('northernlinect', 53),
#  ('rp', 53),
#  ('obama', 53),
#  ('pandemic', 53),
#  ('nbc', 53),
#  ('cdc', 52),
#  ('american', 52),
#  ('big', 52),
#  ('may', 52),
#  ('home', 51),
#  ('video', 51),
#  ('public', 51),
#  ('happy', 51),
#  ('ukraine', 50),
#  ('house', 50),
#  ('media', 50),
#  ('part', 50),
#  ('since', 50),
#  ('check', 50),
#  ('china', 49),
#  ('hes', 49),
#  ('youre', 49),
#  ('getting', 48),
#  ('yet', 48),
#  ('years', 48),
#  ('let', 48),
#  ('thats', 48),
#  ('macron', 47),
#  ('hunterbidenemails', 47),
#  ('ue', 47),
#  ('witter', 47),
#  ('much', 47),
#  ('morning', 47),
#  ('social', 47),
#  ('justice', 47),
#  ('southernlinect', 46),
#  ('whitehouse', 46),
#  ('plan', 46),
#  ('u', 46),
#  ('next', 46),
#  ('also', 46),
#  ('long', 46),
#  ('continue', 45),
#  ('matter', 45),
#  ('youtube', 45),
#  ('women', 45),
#  ('der', 44),
#  ('voteblue', 44),
#  ('come', 44),
#  ('montevistalinect', 43),
#  ('republican', 43),
#  ('proud', 43),
#  ('ca', 43),
#  ('stop', 43),
#  ('nothing', 43),
#  ('hey', 43),
#  ('read', 43),
#  ('beirut', 42),
#  ('kamalaharris', 42),
#  ('country', 42),
#  ('told', 42),
#  ('insurrection', 42),
#  ('hope', 42),
#  ('und', 41),
#  ('truth', 41),
#  ('st', 41),
#  ('better', 41),
#  ('nice', 41),
#  ('florida', 41),
#  ('ny', 41),
#  ('party', 41),
#  ('believe', 41),
#  ('friends', 41),
#  ('corruption', 40),
#  ('bidens', 40),
#  ('‘', 40),
#  ('ive', 40),
#  ('two', 40),
#  ('looking', 40),
#  ('anyone', 40),
#  ('yall', 40),
#  ('racism', 40),
#  ('pretoria', 39),
#  ('elections', 39),
#  ('per', 39),
#  ('wont', 39),
#  ('members', 39),
#  ('put', 39),
#  ('national', 39),
#  ('live', 39),
#  ('emails', 38),
#  ('covidvaccine', 38),
#  ('protect', 38),
#  ('article', 38),
#  ('cnn', 38),
#  ('corrupt', 38),
#  ('link', 38),
#  ('europe', 38),
#  ('epstein', 38),
#  ('political', 38),
#  ('around', 38),
#  ('retreat', 37),
#  ('del', 37),
#  ('na', 37),
#  ('million', 37),
#  ('stopping', 36),
#  ('les', 36),
#  ('congress', 36),
#  ('hospital', 36),
#  ('campaign', 36),
#  ('ago', 36),
#  ('community', 36),
#  ('states', 36),
#  ('away', 36),
#  ('use', 36),
#  ('staysafe', 35),
#  ('security', 35),
#  ('best', 35),
#  ('death', 35),
#  ('call', 35),
#  ('spread', 35),
#  ('gets', 35),
#  ('without', 35),
#  ('censorship', 34),
#  ('des', 34),
#  ('science', 34),
#  ('center', 34),
#  ('times', 34),
#  ('something', 34),
#  ('real', 34),
#  ('ding', 34),
#  ('others', 34),
#  ('world', 34),
#  ('van', 33),
#  ('nbcnews', 33),
#  ('else', 33),
#  ('maybe', 33),
#  ('msnbc', 33),
#  ('beautiful', 33),
#  ('business', 33),
#  ('isnt', 33),
#  ('saying', 33),
#  ('racist', 33),
#  ('tell', 33),
#  ('woman', 33),
#  ('washyourhands', 32),
#  ('burisma', 32),
#  ('dumptrump', 32),
#  ('iowa', 32),
#  ('way', 32),
#  ('someone', 32),
#  ('ever', 32),
#  ('data', 32),
#  ('stayhome', 31),
#  ('positive', 31),
#  ('done', 31),
#  ('supporters', 31),
#  ('guy', 31),
#  ('lost', 31),
#  ('bad', 31),
#  ('attack', 31),
#  ('el', 30),
#  ('mind', 30),
#  ('non', 30),
#  ('already', 30),
#  ('thing', 30),
#  ('important', 30),
#  ('mean', 30),
#  ('hall', 30),
#  ('share', 30),
#  ('shot', 30),
#  ('yes', 30),
#  ('top', 30),
#  ('democracy', 30),
#  ('c', 30),
#  ('left', 30),
#  ('fully', 30),
#  ('deaths', 30),
#  ('everything', 30),
#  ('join', 30),
#  ('indianamericans', 29),
#  ('che', 29),
#  ('email', 29),
#  ('het', 29),
#  ('que', 29),
#  ('healthcare', 29),
#  ('du', 29),
#  ('york', 29),
#  ('always', 29),
#  ('music', 29),
#  ('needs', 29),
#  ('hate', 29),
#  ('seen', 29),
#  ('enough', 29),
#  ('remember', 29),
#  ('win', 29),
#  ('nursing', 28),
#  ('week', 28),
#  ('fake', 28),
#  ('uk', 28),
#  ('boys', 28),
#  ('making', 28),
#  ('actually', 28),
#  ('night', 28),
#  ('men', 28),
#  ('forget', 28),
#  ('children', 28),
#  ('nurse', 27),
#  ('los', 27),
#  ('à', 27),
#  ('voters', 27),
#  ('presidential', 27),
#  ('uselection', 27),
#  ('god', 27),
#  ('change', 27),
#  ('loved', 27),
#  ('record', 27),
#  ('give', 27),
#  ('school', 27),
#  ('art', 27),
#  ('movement', 27),
#  ('little', 27),
#  ('se', 27),
#  ('online', 27),
#  ('month', 27),
#  ('getvaccinated', 26),
#  ('sur', 26),
#  ('con', 26),
#  ('trumpliedkdied', 26),
#  ('fucktrumpsshi', 26),
#  ('shitler', 26),
#  ('murdererinchief', 26),
#  ('negligenthomicide', 26),
#  ('operationmaga', 26),
#  ('ftrumps', 26),
#  ('vetsforscience', 26),
#  ('makeamericaunitedagain', 26),
#  ('infected', 26),
#  ('hold', 26),
#  ('feel', 26),
#  ('using', 26),
#  ('vp', 26),
#  ('end', 26),
#  ('didnt', 26),
#  ('politics', 26),
#  ('person', 26),
#  ('working', 26),
#  ('medical', 26),
#  ('jan', 26),
#  ('job', 26),
#  ('page', 26),
#  ('case', 26),
#  ('hands', 26),
#  ('flattenthecurve', 25),
#  ('fire', 25),
#  ('donaldjtrump', 25),
#  ('trumpcovid', 25),
#  ('pour', 25),
#  ('riot', 25),
#  ('course', 25),
#  ('least', 25),
#  ('behind', 25),
#  ('hell', 25),
#  ('find', 25),
#  ('h', 25),
#  ('gon', 25),
#  ('found', 25),
#  ('start', 25),
#  ('city', 25),
#  ('hear', 25),
#  ('daily', 25),
#  ('listen', 25),
#  ('open', 25),
#  ('report', 25),
#  ('tried', 25),
#  ('stand', 25),
#  ('seditionhunters', 24),
#  ('climateaction', 24),
#  ('queen', 24),
#  ('weeks', 24),
#  ('als', 24),
#  ('ukrainian', 24),
#  ('senate', 24),
#  ('firechucktodd', 24),
#  ('tech', 24),
#  ('oh', 24),
#  ('jack', 24),
#  ('theyre', 24),
#  ('op', 24),
#  ('rn', 24),
#  ('true', 24),
#  ('seems', 24),
#  ('ha', 24),
#  ('anything', 24),
#  ('wait', 24),
#  ('washington', 24),
#  ('reason', 24),
#  ('officer', 24),
#  ('instead', 24),
#  ('especially', 24),
#  ('action', 24),
#  ('information', 24),
#  ('jesuits', 23),
#  ('abc', 23),
#  ('hed', 23),
#  ('een', 23),
#  ('barron', 23),
#  ('far', 23),
#  ('wh', 23),
#  ('money', 23),
#  ('member', 23),
#  ('rt', 23),
#  ('theres', 23),
#  ('ill', 23),
#  ('california', 23),
#  ('save', 23),
#  ('sure', 23),
#  ('sta', 23),
#  ('lot', 23),
#  ('things', 23),
#  ('met', 23),
#  ('soon', 23),
#  ('ask', 23),
#  ('wants', 23),
#  ('arrested', 23),
#  ('fraud', 23),
#  ('fight', 23),
#  ('available', 23),
#  ('f', 23),
#  ('facemask', 22),
#  ('democraticparty', 22),
#  ('trumpisaloser', 22),
#  ('passed', 22),
#  ('è', 22),
#  ('trumpcrimefamily', 22),
#  ('close', 22),
#  ('shouldnt', 22),
#  ('county', 22),
#  ('thanks', 22),
#  ('colleagues', 22),
#  ('heres', 22),
#  ('talking', 22),
#  ('excuses', 22),
#  ('former', 22),
#  ('plus', 22),
#  ('account', 22),
#  ('wouldnt', 22),
#  ('n', 22),
#  ('months', 22),
#  ('court', 22),
#  ('race', 22),
#  ('coming', 22),
#  ('b', 22),
#  ('place', 22),
#  ('capetowntrains', 21),
#  ('tuesdayvibes', 21),
#  ('joebidenjoebidenkamalaharris', 21),
#  ('katyayan', 21),
#  ('tx', 21),
#  ('try', 21),
#  ('zijn', 21),
#  ('indian', 21),
#  ('hasnt', 21),
#  ('hi', 21),
#  ('k', 21),
#  ('donaldjtrumpjr', 21),
#  ('tested', 21),
#  ('democratic', 21),
#  ('vs', 21),
#  ('breaking', 21),
#  ('policy', 21),
#  ('est', 21),
#  ('das', 21),
#  ('votes', 21),
#  ('tha', 21),
#  ('officers', 21),
#  ('shit', 21),
#  ('old', 21),
#  ('january', 21),
#  ('tv', 21),
#  ('retweet', 21),
#  ('reminder', 21),
#  ('charged', 21),
#  ('foxnews', 21),
#  ('point', 21),
#  ('dead', 21),
#  ('wow', 21),
#  ('group', 21),
#  ('government', 21),
#  ('modilies', 20),
#  ('number', 20),
#  ('von', 20),
#  ('harris', 20),
#  ('den', 20),
#  ('source', 20),
#  ('debate', 20),
#  ('due', 20),
#  ('buy', 20),
#  ('wrong', 20),
#  ('talk', 20),
#  ('safety', 20),
#  ('sorry', 20),
#  ('vaccines', 20),
#  ('kind', 20),
#  ('survey', 20),
#  ('whats', 20),
#  ('local', 20),
#  ('whole', 20),
#  ('free', 20),
#  ('full', 20),
#  ('links', 20),
#  ('p', 20),
#  ('nyc', 20),
#  ('shuttleservice', 19),
#  ('np', 19),
#  ('dealing', 19),
#  ('über', 19),
#  ('hoax', 19),
#  ('zu', 19),
#  ('understand', 19),
#  ('ok', 19),
#  ('covidiots', 19),
#  ('pelosi', 19),
#  ('fish', 19),
#  ('arrived', 19),
#  ('asked', 19),
#  ('makes', 19),
#  ('dems', 19),
#  ('latest', 19),
#  ('office', 19),
#  ('george', 19),
#  ('amazing', 19),
#  ('official', 19),
#  ('contact', 19),
#  ('force', 19),
#  ('name', 19),
#  ('order', 19),
#  ('absolutely', 19),
#  ('boy', 19),
#  ('citizens', 19),
#  ('hoek', 18),
#  ('wash', 18),
#  ('varindersingh', 18),
#  ('spring', 18),
#  ('numbers', 18),
#  ('borisjohnson', 18),
#  ('ne', 18),
#  ('qui', 18),
#  ('della', 18),
#  ('pas', 18),
#  ('voor', 18),
#  ('corona', 18),
#  ('für', 18),
#  ('objective', 18),
#  ('solution', 18),
#  ('kag', 18),
#  ('russia', 18),
#  ('icecube', 18),
#  ('lose', 18),
#  ('italia', 18),
#  ('ivankatrump', 18),
#  ('da', 18),
#  ('administration', 18),
#  ('ft', 18),
#  ('peace', 18),
#  ('mans', 18),
#  ('al', 18),
#  ('folks', 18),
#  ('wtf', 18),
#  ('looks', 18),
#  ('sense', 18),
#  ('finds', 18),
#  ('used', 18),
#  ('evidence', 18),
#  ('funny', 18),
#  ('yesterday', 18),
#  ('l', 18),
#  ('ones', 18),
#  ('possible', 18),
#  ('voted', 18),
#  ('kids', 18),
#  ('almost', 18),
#  ('saturday', 18),
#  ('signs', 18),
#  ('insurrectionists', 18),
#  ('hard', 18),
#  ('fighting', 18),
#  ('past', 18),
#  ('rally', 18),
#  ('tweet', 18),
#  ('kill', 18),
#  ('single', 18),
#  ('law', 18),
#  ('storming', 17),
#  ('greene', 17),
#  ('gregabbotttx', 17),
#  ('nowplayingonsplashfm', 17),
#  ('reported', 17),
#  ('genius', 17),
#  ('wake', 17),
#  ('worried', 17),
#  ('mandate', 17),
#  ('democrat', 17),
#  ('boycottnbc', 17),
#  ('hunterbidenlaptop', 17),
#  ('flotus', 17),
#  ('clinton', 17),
#  ('je', 17),
#  ('outside', 17),
#  ('wo', 17),
#  ('design', 17),
#  ('high', 17),
#  ('trial', 17),
#  ('g', 17),
#  ('shows', 17),
#  ('thought', 17),
#  ('ass', 17),
#  ('tuesday', 17),
#  ('push', 17),
#  ('team', 17),
#  ('meanwhile', 17),
#  ('according', 17),
#  ('germany', 17),
#  ('nation', 17),
#  ('word', 17),
#  ('fo', 17),
#  ('arent', 17),
#  ('known', 17),
#  ('power', 17),
#  ('lie', 17),
#  ('taking', 17),
#  ('agree', 17),
#  ('less', 17),
#  ('rights', 17),
#  ('jacobblake', 17),
#  ('across', 17),
#  ('pa', 17),
#  ('child', 17),
#  ('tomorrow', 17),
#  ('front', 17),
#  ('danielprude', 17),
#  ('killed', 17),
#  ('appointee', 16),
#  ('cdcgov', 16),
#  ('guard', 16),
#  ('vaccination', 16),
#  ('socialdistance', 16),
#  ('nose', 16),
#  ('wcovidtr🤡mp', 16),
#  ('treason', 16),
#  ('normal', 16),
#  ('newyorkpost', 16),
#  ('lying', 16),
#  ('bidentownhall', 16),
#  ('wanted', 16),
#  ('second', 16),
#  ('impeached', 16),
#  ('sounds', 16),
#  ('phone', 16),
#  ('protecting', 16),
#  ('hat', 16),
#  ('profile', 16),
#  ('sit', 16),
#  ('si', 16),
#  ('bring', 16),
#  ('education', 16),
#  ('went', 16),
#  ('monday', 16),
#  ('lawyer', 16),
#  ('tonight', 16),
#  ('favorite', 16),
#  ('parents', 16),
#  ('deep', 16),
#  ('question', 16),
#  ('mental', 16),
#  ('summer', 16),
#  ('bombshellmarjorie', 15),
#  ('lineupdateoutboundt', 15),
#  ('wearadamnmask', 15),
#  ('nj', 15),
#  ('approaching', 15),
#  ('pienaarspoorttrain', 15),
#  ('guidelines', 15),
#  ('update', 15),
#  ('sunak', 15),
#  ('nicht', 15),
#  ('giuliani', 15),
#  ('dat', 15),
#  ('dem', 15),
#  ('infectious', 15),
#  ('programming', 15),
#  ('england', 15),
#  ('amyconeybarrett', 15),
#  ('qanon', 15),
#  ('poll', 15),
#  ('twittercensorship', 15),
#  ('mr', 15),
#  ('gopleader', 15),
#  ('guess', 15),
#  ('idea', 15),
#  ('running', 15),
#  ('sad', 15),
#  ('department', 15),
#  ('interesting', 15),
#  ('designer', 15),
#  ('watching', 15),
#  ('decision', 15),
#  ('probably', 15),
#  ('lol', 15),
#  ('living', 15),
#  ('interview', 15),
#  ('oday', 15),
#  ('problem', 15),
#  ('sick', 15),
#  ('worse', 15),
#  ('knew', 15),
#  ('rest', 15),
#  ('forward', 15),
#  ('wonder', 15),
#  ('podcast', 15),
#  ('nd', 15),
#  ('app', 15),
#  ('info', 15),
#  ('human', 15),
#  ('episode', 15),
#  ('gave', 15),
#  ('senategop', 15),
#  ('wednesday', 15),
#  ('mother', 15),
#  ('sign', 15),
#  ('demand', 15),
#  ('projectlincoln', 15),
#  ('leave', 15),
#  ('hours', 15),
#  ('nature', 15),
#  ('gopcomplicittraitors', 14),
#  ('berailsma', 14),
#  ('distancing', 14),
#  ('realfloodbaba', 14),
#  ('breakfastjam', 14),
#  ('med', 14),
#  ('mabopanetrain', 14),
#  ('amber', 14),
#  ('obviously', 14),
#  ('ftse', 14),
#  ('lil', 14),
#  ('publicly', 14),
#  ('wasnt', 14),
#  ('hillaryclinton', 14),
#  ('means', 14),
#  ('brave', 14),
#  ('figlio', 14),
#  ('una', 14),
#  ('excuse', 14),
#  ('ein', 14),
#  ('debates', 14),
#  ('polls', 14),
#  ('become', 14),
#  ('putin', 14),
#  ('tbt', 14),
#  ('restrictions', 14),
#  ('trumprally', 14),
#  ('fiverr', 14),
#  ('entire', 14),
#  ('comes', 14),
#  ('trending', 14),
#  ('knows', 14),
#  ('censoring', 14),
#  ('engineer', 14),
#  ('facts', 14),
#  ('dei', 14),
#  ('scandal', 14),
#  ('act', 14),
#  ('mouth', 14),
#  ('chance', 14),
#  ('jr', 14),
#  ('moving', 14),
#  ('cover', 14),
#  ('accountable', 14),
#  ('words', 14),
#  ('happen', 14),
#  ('increase', 14),
#  ('hearing', 14),
#  ('risk', 14),
#  ('governor', 14),
#  ('nytimes', 14),
#  ('terrorism', 14),
#  ('antifa', 14),
#  ('early', 14),
#  ('might', 14),
#  ('communities', 14),
#  ('ou', 14),
#  ('color', 14),
#  ('powerful', 14),
#  ('bc', 14),
#  ('blue', 14),
#  ('step', 14),
#  ('called', 14),
#  ('happened', 14),
#  ('protesters', 14),
#  ('violence', 14),
#  ('heard', 14),
#  ('stories', 14),
#  ('common', 14),
#  ('abuse', 14),
#  ('directly', 14),
#  ('calling', 14),
#  ('took', 14),
#  ('game', 14),
#  ('freedom', 14),
#  ('shop', 14),
#  ('maskup', 13),
#  ('cna', 13),
#  ('weekend', 13),
#  ('april', 13),
#  ('handmade', 13),
#  ('princeharry', 13),
#  ('princewilliam', 13),
#  ('football', 13),
#  ('cad', 13),
#  ('daydesign', 13),
#  ('gigs', 13),
#  ('freelance', 13),
#  ('kitchen', 13),
#  ('commercial', 13),
#  ('commercialkitchendesignkitchenlayout', 13),
#  ('remote', 13),
#  ('total', 13),
#  ('fauci', 13),
#  ('able', 13),
#  ('artikel', 13),
#  ('jail', 13),
#  ('americanpeople', 13),
#  ('uselections', 13),
#  ('maar', 13),
#  ('personal', 13),
#  ('mit', 13),
#  ('break', 13),
#  ('slow', 13),
#  ('au', 13),
#  ('er', 13),
#  ('liar', 13),
#  ('trumpcovidhoax', 13),
#  ('north', 13),
#  ('es', 13),
#  ('trumppence', 13),
#  ('ice', 13),
#  ('socialdistancing', 13),
#  ('economy', 13),
#  ('losing', 13),
#  ('tax', 13),
#  ('loro', 13),
#  ('anche', 13),
#  ('erictrump', 13),
#  ('gopchairwoman', 13),
#  ('wins', 13),
#  ('joebidens', 13),
#  ('air', 13),
#  ('su', 13),
#  ('message', 13),
#  ('pro', 13),
#  ('clear', 13),
#  ('father', 13),
#  ('director', 13),
#  ('blame', 13),
#  ('war', 13),
#  ('smart', 13),
#  ('shedding', 13),
#  ('r', 13),
#  ('ready', 13),
#  ('rioters', 13),
#  ('deleted', 13),
#  ('cop', 13),
#  ('v', 13),
#  ('several', 13),
#  ('learn', 13),
#  ('records', 13),
#  ('students', 13),
#  ('mom', 13),
#  ('excited', 13),
#  ('song', 13),
#  ('released', 13),
#  ('book', 13),
#  ('honor', 13),
#  ('worker', 13),
#  ('food', 13),
#  ('happening', 13),
#  ('ahmaud', 13),
#  ('saw', 13),
#  ('moment', 13),
#  ('friday', 13),
#  ('rapper', 12),
#  ('wayne', 12),
#  ('pardonso', 12),
#  ('begged', 12),
#  ('indoors', 12),
#  ('amazon', 12),
#  ('dream', 12),
#  ('san', 12),
#  ('fl', 12),
#  ('saulsville', 12),
#  ('saulsvilletrain', 12),
#  ('washable', 12),
#  ('splashfm', 12),
#  ('chairman', 12),
#  ('princeandrew', 12),
#  ('play', 12),
#  ('traitors', 12),
#  ('prosecutor', 12),
#  ('hunterscrackpipe', 12),
#  ('crazy', 12),
#  ('lockdown', 12),
#  ('dad', 12),
#  ('niet', 12),
#  ('candidate', 12),
#  ('co', 12),
#  ('telling', 12),
#  ('stimulus', 12),
#  ('criminal', 12),
#  ('tweets', 12),
#  ('dan', 12),
#  ('wie', 12),
#  ('–', 12),
#  ('fucking', 12),
#  ('laptop', 12),
#  ('rule', 12),
#  ('turn', 12),
#  ('nbcnewsisaselloutof', 12),
#  ('savannahguthrie', 12),
#  ('bye', 12),
#  ('nbctownhall', 12),
#  ('unchoiced', 12),
#  ('uncoupling', 12),
#  ('dvr', 12),
#  ('electionday', 12),
#  ('selfie', 12),
#  ('fashion', 12),
#  ('gun', 12),
#  ('bidenharristosaveamerica', 12),
#  ('speakerpelosi', 12),
#  ('brain', 12),
#  ('washingtonpost', 12),
#  ('yrs', 12),
#  ('results', 12),
#  ('questo', 12),
#  ('sistema', 12),
#  ...]

# %% [markdown]
# Create a new column, concatenating all words that are tokenized/stemmed into a single string

# %%
df2['stem_full'] = df2['stem'].apply(lambda x: ' '.join(x))
df2['token_full'] = df2['token'].apply(lambda x: ' '.join(x))
df2
# Out:
#       Train_id                                              tweet  \
# 0            1  congratulations rrhdr and publichealthumn so h...
# 1            2  he same people who perpetrated the whitesuprem...
# 2            3  fannie lou hamerblackhistoryblackhistorymonthb...
# 3            4  kylandyoung williamcson  million properly dist...
# 4            5  its the colors for the month for meblacklivesm...
# ...        ...                                                ...
# 5959      5960   members of the us capitol police force   nati...
# 5960      5961  excuses dont excuse the republicans have  excu...
# 5961      5962  here were hundreds of crimes committed on jan ...
# 5962      5963  simonwghost im creating ingoditrustrioter to k...
# 5963      5964  kaoconnor i repeat trump is not a victimhe is ...
#
#                                                   token  \
# 0     [congratulations, rrhdr, publichealthumn, happ...
# 1     [people, perpetrated, whitesupremacy, domestic...
# 2     [fannie, lou, hamerblackhistoryblackhistorymon...
# 3     [kylandyoung, williamcson, million, properly, ...
# 4     [colors, month, meblacklivesmatterthats, thats...
# ...                                                 ...
# 5959  [members, us, capitol, police, force, national...
# 5960  [excuses, dont, excuse, republicans, excuses, ...
# 5961  [hundreds, crimes, committed, jan, capitol, hu...
# 5962  [simonwghost, im, creating, ingoditrustrioter,...
# 5963  [kaoconnor, repeat, trump, victimhe, predatort...
#
#                                                    stem  \
# 0     [congratul, rrhdr, publichealthumn, happi, see...
# 1     [peopl, perpetr, whitesupremaci, domesticterro...
# 2     [fanni, lou, hamerblackhistoryblackhistorymont...
# 3     [kylandyoung, williamcson, million, proper, di...
# 4     [color, month, meblacklivesmatterthat, that, p...
# ...                                                 ...
# 5959  [member, us, capitol, polic, forc, nation, gua...
# 5960  [excus, dont, excus, republican, excus, should...
# 5961  [hundr, crime, commit, jan, capitol, hundr, do...
# 5962  [simonwghost, im, creat, ingoditrustriot, keep...
# 5963  [kaoconnor, repeat, trump, victimh, predatorth...
#
#                                               stem_full  \
# 0     congratul rrhdr publichealthumn happi see mn s...
# 1     peopl perpetr whitesupremaci domesticterrorist...
# 2     fanni lou hamerblackhistoryblackhistorymonthbl...
# 3     kylandyoung williamcson million proper distrib...
# 4     color month meblacklivesmatterthat that post b...
# ...                                                 ...
# 5959  member us capitol polic forc nation guard memb...
# 5960  excus dont excus republican excus shouldnt imp...
# 5961  hundr crime commit jan capitol hundr dont make...
# 5962  simonwghost im creat ingoditrustriot keep tab ...
# 5963  kaoconnor repeat trump victimh predatorthes ma...
#
#                                              token_full
# 0     congratulations rrhdr publichealthumn happy se...
# 1     people perpetrated whitesupremacy domesticterr...
# 2     fannie lou hamerblackhistoryblackhistorymonthb...
# 3     kylandyoung williamcson million properly distr...
# 4     colors month meblacklivesmatterthats thats pos...
# ...                                                 ...
# 5959  members us capitol police force national guard...
# 5960  excuses dont excuse republicans excuses should...
# 5961  hundreds crimes committed jan capitol hundreds...
# 5962  simonwghost im creating ingoditrustrioter keep...
# 5963  kaoconnor repeat trump victimhe predatorthese ...
#
# [5964 rows x 6 columns]

# %% [markdown]
# # Training a model
# ## Start with Naive Bayes  (Scored 0.734)

# %%
# corpus = X_train
# y = y_train
# corpus2 = x_test
# y_pred = predicted y labels


clf = Pipeline([('vect', CountVectorizer()), ('tfidf', TfidfTransformer()), ('clf', MultinomialNB())])
clf = clf.fit(corpus, y)

corpus2 = df2['stem_full']
y_pred = clf.predict(corpus2)

# %%
df_nb = pd.read_csv("mdss-basic-stream/test_basic.csv")
df_nb['label'] = y_pred

# %% [markdown]
# #### To CSV

# %%
df_nb.drop(['tweet'],axis=1,inplace=True)

# %%
df_nb.to_csv("submission_nb_new.csv", index=False)

# %% [markdown]
# # SVM with stemmed words (Scored 0.83)

# %%
from sklearn.linear_model import SGDClassifier

# corpus = X_train
# y = y_train
# corpus2 = x_test
# y_pred = predicted y labels

sgd = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, random_state=42, max_iter=5, tol=None)),
               ])
sgd.fit(corpus, y)

corpus2 = df2['stem_full']
y_pred_svm = clf.predict(corpus2)

df_svm = pd.read_csv("mdss-basic-stream/test_basic.csv")
df_svm['label'] = y_pred_svm

# %% [markdown]
# #### To CSV

# %%
df_svm.drop(['tweet'],axis=1,inplace=True)

# %%
df_svm.to_csv("submission_svm_new.csv", index=False)

# %% [markdown]
# # SVM with tokenized (not stemmed) words (Scored 0.83)

# %%
# SVM
sgd_tok = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, random_state=42, max_iter=5, tol=None)),
               ])
sgd_tok.fit(corpus_tok, y)

corpus_tok_svm = df2['stem_full']
y_pred_tok_svm = sgd_tok.predict(corpus_tok_svm)

df_svm_tok = pd.read_csv("mdss-basic-stream/test_basic.csv")
df_svm_tok['label'] = y_pred_tok_svm

# %% [markdown]
# #### To CSV

# %%
df_svm_tok.drop(['tweet'],axis=1,inplace=True)

# %%
df_svm_tok.to_csv("submission_svm_tokenised_new.csv", index=False)
